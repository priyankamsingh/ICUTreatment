# %% [markdown]
# #### Run the DQN model on Extended space data

# %%
import os
import sys
import joblib 
from datetime import datetime 
import time
from multiprocessing import cpu_count 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce
from sklearn.model_selection import ParameterGrid
import torch 
from torch import optim , nn 
from luca_utils import train_model_double, dueling_net
use_gpu = torch.cuda.is_available()

# %%
### Experiment name 
exp_name = 'lucspace'

### OPTIONAL: Continue training
continue_training = False
cont_exp_grid_run = 0
original_exp_name = exp_name

#### super OPTIONAL: Continue training a previous interim model
continue_interim = False
continue_interim_i = 0

# %%
# import your RL data dict from this directory 
data_dir = 'C:/Users/gmpxe/Downloads/MIMIC_data_allbins.csv/Luca_experiment/data/'
dict_file = 'Luca_data_dict.pkl'

# Give path to model dir 
model_dir = 'C:/Users/gmpxe/Downloads/MIMIC_data_allbins.csv/Luca_experiment/models/'
interimdir = 'C:/Users/gmpxe/Downloads/MIMIC_data_allbins.csv/Luca_experiment/interimfiles/'
performance_dir = 'C:/Users/gmpxe/Downloads/MIMIC_data_allbins.csv/Luca_experiment/performance/'

## experiment dir 
exp_dir = 'C:/Users/gmpxe/Downloads/MIMIC_data_allbins.csv/Luca_experiment/'

# %% [markdown]
# #### Read required file for model building

# %%
## Reading RL data 
data_dict = joblib.load(os.path.join(data_dir, 'Luca_data_dict.pkl'))

# Action probabilities of physician's action used for intermediate evaluateion
train_pi_behavior = pd.read_pickle(os.path.join(data_dir, 'KNN_pi_behavior_' + 'train' + 'data.pkl')) # pi_evaluation
val_pi_behavior = pd.read_pickle(os.path.join(data_dir, 'KNN_pi_behavior_' + 'val' + 'data.pkl')) # pi_evaluation
test_pi_behavior = pd.read_pickle(os.path.join(data_dir, 'KNN_pi_behavior_' + 'test' + 'data.pkl')) # pi_evaluation

# dataset MDP Q function (FQI-SARSA)
train_MDP_Q = pd.read_pickle(os.path.join(data_dir, 'FQI_QValues_' + 'train' + 'data.pkl'))
val_MDP_Q = pd.read_pickle(os.path.join(data_dir, 'FQI_QValues_' + 'val' + 'data.pkl'))
test_MDP_Q = pd.read_pickle(os.path.join(data_dir, 'FQI_QValues_' + 'test' + 'data.pkl'))

#create MDP dictionary to pass to teh model 
data_dict_MDP = {'train_pi_behavior': train_pi_behavior,
                 'val_pi_behavior': val_pi_behavior,
                 'test_pi_behavior': test_pi_behavior,
                 'train_MDP_Q': train_MDP_Q,
                 'val_MDP_Q': val_MDP_Q,
                 'test_MDP_Q': test_MDP_Q
                }

# %%
###################
# define hyperparameter tuning grid
param_options = {   'state_dim' :         [data_dict['train']['X'].shape[1]],  
                    'action_dim' :        [21],                                 
                    'gamma' :             [0.9],                              
                    'batch_size' :        [32],#, 64],#,128],                        
                    'lr' :                [1e-4],                               
                    'num_epochs' :        [350000],                             
                    'hidden_dim' :        [128],# 256],                           
                    'num_hidden' :        [2],                       
                    'drop_prob' :         [0.0],                         
                    'option' :            ['linear'],                  
                    'use_scheduler':      ['StepLR'],                       
                    'scheduler_gamma':    [0.9],#,0.99],                       
                    'sched_step_size':    [25000],#,50000],                  
                    'tau':                [1e-4],                       
                    'reg_lambda' :        [5],                            
                    'REWARD_THRESHOLD' :  [15],                               
                    'PER_beta_start' :    [0.9],                             
                    'PER_alpha' :         [0.6],                        
                    'PER_epsilon' :       [0.01],                      
                    'PER_sample_alpha' :  [0.0],                            
                    'PER_start_prob' :    [0.001],                          
                    'use_GPU':            [use_gpu],                            
                    'tracking_step_eval':           [5000],                     
                    'tracking_step_interim_model':  [5000],                     
                    'tracking_console_print':       [1000]                      
         }

## Create parameter grid 
config_grid = ParameterGrid(param_options)

# %%
print('\n-----------------\nSTART EXPERIMENT')
print("experiment: " + exp_name)
print("Started at: " + str(datetime.now()) + "\n-----------------")
total_since = time.time()
exp_grid_run = 0
# For each configuration LOOP
for config in config_grid:
    exp_grid_run +=1
    if not os.path.exists(os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) )):
        os.makedirs(os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) ))

    ###################
    ### Models
    model = dueling_net(D_in=config['state_dim'],
                        H=config['hidden_dim'],
                        D_out=config['action_dim'],
                        drop_prob=config['drop_prob'],
                        num_hidden=config['num_hidden'],
                        option=config['option']
                        )

    target_model = dueling_net(D_in=config['state_dim'],
                               H=config['hidden_dim'],
                               D_out=config['action_dim'],
                               drop_prob=config['drop_prob'],
                               num_hidden=config['num_hidden'],
                               option=config['option']
                               )
        
    ###################
    ### Optimizer
    optimizer = optim.Adam([{'params': model.parameters()}],
                           lr=config['lr'])

    ###################
    ### Scheduler
    if config['use_scheduler'] == 'ReduceLROnPlateau':
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', verbose=True)
    elif config['use_scheduler'] == 'StepLR':      
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=config['scheduler_gamma']) # step size applied with config['sched_step_size'] in util.py train function
    else:
        scheduler = None

    def weights_init(m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight.data).float()   
            
    ###################
    ### Create CONFIG dataframe for saving to disk
    config_df = pd.DataFrame(config, index=[0])
            
    ###################
    # OPTIONAL: Load previous model    
    if continue_training: 
        
        ###################
        # This is a mess
        exp_name = original_exp_name + '_' + str(cont_exp_grid_run) + '_continued'
        new_exp_dir = os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) )
        
        # create model_continued model directory
        if not os.path.exists(new_exp_dir):
            os.makedirs(new_exp_dir)
        
        # load moel
        if continue_interim: 
            exp_model = original_exp_name + '/models/' + original_exp_name + '_' + str(cont_exp_grid_run) + '/' + original_exp_name + '_' + str(cont_exp_grid_run) + '_interim_' + str(continue_interim_i) + '_iteration_model.chk'
        else:
            exp_model = original_exp_name + '/models/' + original_exp_name + '_' + str(cont_exp_grid_run) + '_model.chk'
            
        #selected_model = os.path.join(conf.EXP_DIR, exp_model) 
        selected_model = os.path.join(exp_model)

        ###################    
        # CPU or GPU, let the budget decide!  
        if use_gpu:
            model = model.cuda()
            target_model = target_model.cuda()
            model.load_state_dict(torch.load(selected_model))
            target_model.load_state_dict(torch.load(selected_model))
        else:
            model.load_state_dict(torch.load(selected_model, map_location=lambda storage, loc: storage))
            target_model.load_state_dict(torch.load(selected_model, map_location=lambda storage, loc: storage))
        
        ###################
        # experiment name and location for interim model saving
        experiment = { 'exp_name': exp_name, 'exp_dir': exp_dir, 'exp_grid_run': exp_grid_run, 'exp_grid_total_runs': len(config_grid) }
            
        # Save CONFIG dataframe to disk and set location for FINAL model saving 
        checkpoints_path = os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) + '_model.chk')
        config_df.to_csv(os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) + '_config.csv'), index=False)
        
    ###################
    # IF NOT LOADING PREVIOUS MODEL, START FRESH
    else:
        ###################
        # initialize model weights
        model.apply(weights_init)
        target_model.apply(weights_init)
        if use_gpu:
            model = model.cuda()
            target_model = target_model.cuda()
            
        # experiment name and location for interim model saving
        experiment = { 'exp_name': exp_name, 'exp_dir': exp_dir, 'exp_grid_run': exp_grid_run, 'exp_grid_total_runs': len(config_grid) }
    
        ###################
        # Save CONFIG dataframe to disk and set location for FINAL model saving
        checkpoints_path = os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) + '_model.chk')
        config_df.to_csv(os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) + '_config.csv'), index=False)

        
    ############################################################################  
    if continue_training:
        print('\n-----------------\nSTART CONTINUED MODEL TRAINING')
    else:        
        print('\n-----------------\nSTART MODEL TRAINING')
    print("Experiment name: " + exp_name)
    print("Experiment " + str(exp_grid_run) + ' out of ' + str(len(config_grid)))
    print("configuration of model: ")
    print('-----------------')
   
    ###################
    # This is probably what your looking for, the actual model training... it's at the end of util.py, you're welcome!
    tracking_performance_dict, performance_dict, best_model = train_model_double(model=model,
                                                                                 target_model=target_model,
                                                                                 data_dict=data_dict,
                                                                                 data_dict_MDP=data_dict_MDP,
                                                                                 config=config,
                                                                                 optimizer=optimizer,
                                                                                 scheduler=scheduler,
                                                                                 experiment=experiment,
                                                                                 use_gpu=use_gpu)

    ###################
    # save best model of this config run
    torch.save(best_model.state_dict(), checkpoints_path)
    
    # create dictionaries
    performance_df = pd.DataFrame.from_dict(performance_dict)
    tracking_performance_df = pd.DataFrame.from_dict(tracking_performance_dict)

    # write to csv
    tracking_performance_df.to_csv(os.path.join(exp_dir, 'performance/' + exp_name + "_" + str(exp_grid_run) + '_tracking_performance.csv'), index=False)
    performance_df.to_csv(os.path.join(exp_dir, 'performance/' + exp_name + "_" + str(exp_grid_run) + '_performance.csv'), index=False)
    
################################################################################################################
################################################################################################################
time_elapsed = time.time() - total_since
hours = time_elapsed//3600
temp = time_elapsed - 3600*hours
minutes = temp//60
seconds = temp - 60*minutes
print('\n-----------------\nFINISHED TRAINING ALL EXPERIMENTS\n-----------------')
print(exp_name)
print("Finished at: " + str(datetime.now()))
print('Experiment complete in %d hours, %d minutes and %d seconds' %(hours,minutes,seconds))
# Out:
# -----------------
# START EXPERIMENT
# experiment: lucspace
# Started at: 2022-06-10 10:42:29.867845
# -----------------
#
# -----------------
# START MODEL TRAINING
# Experiment name: lucspace
# Experiment 1 out of 1
# configuration of model:
# -----------------
# ----------
# Epoch 1000/350000
#  batch loss:  0.178
#  running loss:  13.529
#  batch error:  13.159
#  batch avg Phy Q value:  2.466
#  batch avg DQN Q value:  3.563
#  batch mean DQN best action probability:  29.03 %
# ----------
# Epoch 2000/350000
#  batch loss:  0.173
#  running loss:  13.103
#  batch error:  12.887
#  batch avg Phy Q value:  2.898
#  batch avg DQN Q value:  3.966
#  batch mean DQN best action probability:  29.756 %
# ----------
# Epoch 3000/350000
#  batch loss:  0.155
#  running loss:  12.796
#  batch error:  11.961
#  batch avg Phy Q value:  3.2
#  batch avg DQN Q value:  4.203
#  batch mean DQN best action probability:  30.145 %
# ----------
# Epoch 4000/350000
#  batch loss:  0.154
#  running loss:  12.593
#  batch error:  11.847
#  batch avg Phy Q value:  3.348
#  batch avg DQN Q value:  4.403
#  batch mean DQN best action probability:  29.776 %
# ----------
# Epoch 5000/350000
#  batch loss:  0.146
#  running loss:  12.426
#  batch error:  11.28
#  batch avg Phy Q value:  3.569
#  batch avg DQN Q value:  4.688
#  batch mean DQN best action probability:  34.779 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.778
# DQN WIS: 2.49
# train
# DQN WDR_: 7.664
# DQN WIS_: 2.49
# ----------
# val
# DQN WDR: 0.114
# DQN WIS: 2.274
# val
# DQN WDR_: 8.093
# DQN WIS_: 2.274
# ----------
# test
# DQN WDR: 0.093
# DQN WIS: -2.262
# test
# DQN WDR_: 2.834
# DQN WIS_: -2.262
# ----------
# ----------
# Saving interim Model 5000
# ----------
# ----------
# Epoch 6000/350000
#  batch loss:  0.149
#  running loss:  12.299
#  batch error:  11.894
#  batch avg Phy Q value:  3.538
#  batch avg DQN Q value:  4.579
#  batch mean DQN best action probability:  31.993 %
# ----------
# Epoch 7000/350000
#  batch loss:  0.155
#  running loss:  12.191
#  batch error:  11.814
#  batch avg Phy Q value:  3.833
#  batch avg DQN Q value:  4.64
#  batch mean DQN best action probability:  30.675 %
# ----------
# Epoch 8000/350000
#  batch loss:  0.141
#  running loss:  12.099
#  batch error:  11.59
#  batch avg Phy Q value:  3.785
#  batch avg DQN Q value:  4.821
#  batch mean DQN best action probability:  31.808 %
# ----------
# Epoch 9000/350000
#  batch loss:  0.151
#  running loss:  12.009
#  batch error:  11.919
#  batch avg Phy Q value:  3.346
#  batch avg DQN Q value:  4.708
#  batch mean DQN best action probability:  29.182 %
# ----------
# Epoch 10000/350000
#  batch loss:  0.128
#  running loss:  11.929
#  batch error:  10.684
#  batch avg Phy Q value:  3.726
#  batch avg DQN Q value:  4.931
#  batch mean DQN best action probability:  32.164 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.577
# DQN WIS: 2.483
# train
# DQN WDR_: 8.906
# DQN WIS_: 2.483
# ----------
# val
# DQN WDR: -3.864
# DQN WIS: -1.678
# val
# DQN WDR_: 3.47
# DQN WIS_: -1.678
# ----------
# test
# DQN WDR: 0.147
# DQN WIS: -1.938
# test
# DQN WDR_: 1.742
# DQN WIS_: -1.938
# ----------
# ----------
# Saving interim Model 10000
# ----------
# ----------
# Epoch 11000/350000
#  batch loss:  0.164
#  running loss:  11.853
#  batch error:  12.302
#  batch avg Phy Q value:  3.815
#  batch avg DQN Q value:  5.0
#  batch mean DQN best action probability:  33.283 %
# ----------
# Epoch 12000/350000
#  batch loss:  0.126
#  running loss:  11.787
#  batch error:  10.223
#  batch avg Phy Q value:  4.042
#  batch avg DQN Q value:  4.975
#  batch mean DQN best action probability:  33.567 %
# ----------
# Epoch 13000/350000
#  batch loss:  0.133
#  running loss:  11.725
#  batch error:  10.947
#  batch avg Phy Q value:  4.145
#  batch avg DQN Q value:  4.762
#  batch mean DQN best action probability:  29.255 %
# ----------
# Epoch 14000/350000
#  batch loss:  0.138
#  running loss:  11.663
#  batch error:  11.051
#  batch avg Phy Q value:  4.358
#  batch avg DQN Q value:  4.975
#  batch mean DQN best action probability:  30.17 %
# ----------
# Epoch 15000/350000
#  batch loss:  0.126
#  running loss:  11.6
#  batch error:  10.107
#  batch avg Phy Q value:  3.798
#  batch avg DQN Q value:  4.797
#  batch mean DQN best action probability:  25.226 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.798
# DQN WIS: 2.497
# train
# DQN WDR_: 10.63
# DQN WIS_: 2.497
# ----------
# val
# DQN WDR: -0.332
# DQN WIS: 2.393
# val
# DQN WDR_: 8.039
# DQN WIS_: 2.393
# ----------
# test
# DQN WDR: -0.036
# DQN WIS: -1.459
# test
# DQN WDR_: 3.698
# DQN WIS_: -1.459
# ----------
# ----------
# Saving interim Model 15000
# ----------
# ----------
# Epoch 16000/350000
#  batch loss:  0.121
#  running loss:  11.534
#  batch error:  10.011
#  batch avg Phy Q value:  4.47
#  batch avg DQN Q value:  5.225
#  batch mean DQN best action probability:  30.1 %
# ----------
# Epoch 17000/350000
#  batch loss:  0.147
#  running loss:  11.469
#  batch error:  10.601
#  batch avg Phy Q value:  3.958
#  batch avg DQN Q value:  5.234
#  batch mean DQN best action probability:  29.375 %
# ----------
# Epoch 18000/350000
#  batch loss:  0.112
#  running loss:  11.411
#  batch error:  10.105
#  batch avg Phy Q value:  4.39
#  batch avg DQN Q value:  5.56
#  batch mean DQN best action probability:  34.642 %
# ----------
# Epoch 19000/350000
#  batch loss:  0.162
#  running loss:  11.355
#  batch error:  11.666
#  batch avg Phy Q value:  4.369
#  batch avg DQN Q value:  5.075
#  batch mean DQN best action probability:  27.274 %
# ----------
# Epoch 20000/350000
#  batch loss:  0.112
#  running loss:  11.305
#  batch error:  9.28
#  batch avg Phy Q value:  4.581
#  batch avg DQN Q value:  5.28
#  batch mean DQN best action probability:  28.483 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.596
# DQN WIS: 2.494
# train
# DQN WDR_: 9.194
# DQN WIS_: 2.494
# ----------
# val
# DQN WDR: -3.251
# DQN WIS: -1.126
# val
# DQN WDR_: 4.492
# DQN WIS_: -1.126
# ----------
# test
# DQN WDR: 3.569
# DQN WIS: 2.467
# test
# DQN WDR_: 7.82
# DQN WIS_: 2.467
# ----------
# ----------
# Saving interim Model 20000
# ----------
# ----------
# Epoch 21000/350000
#  batch loss:  0.108
#  running loss:  11.253
#  batch error:  9.779
#  batch avg Phy Q value:  4.592
#  batch avg DQN Q value:  5.346
#  batch mean DQN best action probability:  28.728 %
# ----------
# Epoch 22000/350000
#  batch loss:  0.122
#  running loss:  11.204
#  batch error:  10.186
#  batch avg Phy Q value:  4.646
#  batch avg DQN Q value:  5.392
#  batch mean DQN best action probability:  27.22 %
# ----------
# Epoch 23000/350000
#  batch loss:  0.119
#  running loss:  11.153
#  batch error:  10.286
#  batch avg Phy Q value:  4.383
#  batch avg DQN Q value:  5.652
#  batch mean DQN best action probability:  33.125 %
# ----------
# Epoch 24000/350000
#  batch loss:  0.133
#  running loss:  11.1
#  batch error:  10.536
#  batch avg Phy Q value:  4.409
#  batch avg DQN Q value:  5.603
#  batch mean DQN best action probability:  27.963 %
# ----------
# Epoch 25000/350000
#  batch loss:  0.158
#  running loss:  11.045
#  batch error:  11.352
#  batch avg Phy Q value:  5.261
#  batch avg DQN Q value:  6.034
#  batch mean DQN best action probability:  32.994 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.266
# DQN WIS: 2.492
# train
# DQN WDR_: 8.537
# DQN WIS_: 2.492
# ----------
# val
# DQN WDR: -4.293
# DQN WIS: -2.325
# val
# DQN WDR_: 2.703
# DQN WIS_: -2.325
# ----------
# test
# DQN WDR: 3.507
# DQN WIS: 2.496
# test
# DQN WDR_: 6.313
# DQN WIS_: 2.496
# ----------
# ----------
# Saving interim Model 25000
# ----------
# ----------
# Epoch 26000/350000
#  batch loss:  0.131
#  running loss:  10.997
#  batch error:  10.294
#  batch avg Phy Q value:  4.968
#  batch avg DQN Q value:  5.741
#  batch mean DQN best action probability:  28.158 %
# ----------
# Epoch 27000/350000
#  batch loss:  0.114
#  running loss:  10.951
#  batch error:  9.55
#  batch avg Phy Q value:  4.647
#  batch avg DQN Q value:  5.856
#  batch mean DQN best action probability:  30.099 %
# ----------
# Epoch 28000/350000
#  batch loss:  0.117
#  running loss:  10.905
#  batch error:  9.279
#  batch avg Phy Q value:  5.007
#  batch avg DQN Q value:  5.895
#  batch mean DQN best action probability:  30.004 %
# ----------
# Epoch 29000/350000
#  batch loss:  0.102
#  running loss:  10.858
#  batch error:  9.505
#  batch avg Phy Q value:  5.438
#  batch avg DQN Q value:  6.046
#  batch mean DQN best action probability:  32.309 %
# ----------
# Epoch 30000/350000
#  batch loss:  0.121
#  running loss:  10.81
#  batch error:  9.887
#  batch avg Phy Q value:  4.595
#  batch avg DQN Q value:  5.933
#  batch mean DQN best action probability:  30.309 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.352
# DQN WIS: 2.501
# train
# DQN WDR_: 8.826
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: -0.14
# DQN WIS: 1.765
# val
# DQN WDR_: 8.321
# DQN WIS_: 1.765
# ----------
# test
# DQN WDR: 3.356
# DQN WIS: 2.499
# test
# DQN WDR_: 8.482
# DQN WIS_: 2.499
# ----------
# ----------
# Saving interim Model 30000
# ----------
# ----------
# Epoch 31000/350000
#  batch loss:  0.095
#  running loss:  10.762
#  batch error:  8.419
#  batch avg Phy Q value:  5.532
#  batch avg DQN Q value:  6.419
#  batch mean DQN best action probability:  34.609 %
# ----------
# Epoch 32000/350000
#  batch loss:  0.164
#  running loss:  10.715
#  batch error:  9.804
#  batch avg Phy Q value:  4.948
#  batch avg DQN Q value:  6.158
#  batch mean DQN best action probability:  29.565 %
# ----------
# Epoch 33000/350000
#  batch loss:  0.117
#  running loss:  10.67
#  batch error:  9.563
#  batch avg Phy Q value:  5.481
#  batch avg DQN Q value:  6.249
#  batch mean DQN best action probability:  31.128 %
# ----------
# Epoch 34000/350000
#  batch loss:  0.075
#  running loss:  10.628
#  batch error:  7.503
#  batch avg Phy Q value:  5.185
#  batch avg DQN Q value:  6.082
#  batch mean DQN best action probability:  28.68 %
# ----------
# Epoch 35000/350000
#  batch loss:  0.114
#  running loss:  10.586
#  batch error:  9.765
#  batch avg Phy Q value:  5.506
#  batch avg DQN Q value:  6.414
#  batch mean DQN best action probability:  33.427 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.603
# DQN WIS: 2.502
# train
# DQN WDR_: 7.649
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 1.09
# DQN WIS: 2.369
# val
# DQN WDR_: 7.219
# DQN WIS_: 2.369
# ----------
# test
# DQN WDR: 3.383
# DQN WIS: 2.495
# test
# DQN WDR_: 9.792
# DQN WIS_: 2.495
# ----------
# ----------
# Saving interim Model 35000
# ----------
# ----------
# Epoch 36000/350000
#  batch loss:  0.113
#  running loss:  10.544
#  batch error:  9.36
#  batch avg Phy Q value:  5.538
#  batch avg DQN Q value:  6.437
#  batch mean DQN best action probability:  34.092 %
# ----------
# Epoch 37000/350000
#  batch loss:  0.139
#  running loss:  10.503
#  batch error:  6.778
#  batch avg Phy Q value:  5.576
#  batch avg DQN Q value:  6.422
#  batch mean DQN best action probability:  30.223 %
# ----------
# Epoch 38000/350000
#  batch loss:  0.096
#  running loss:  10.463
#  batch error:  8.171
#  batch avg Phy Q value:  5.613
#  batch avg DQN Q value:  6.567
#  batch mean DQN best action probability:  33.23 %
# ----------
# Epoch 39000/350000
#  batch loss:  0.104
#  running loss:  10.424
#  batch error:  8.466
#  batch avg Phy Q value:  6.027
#  batch avg DQN Q value:  6.791
#  batch mean DQN best action probability:  33.599 %
# ----------
# Epoch 40000/350000
#  batch loss:  0.175
#  running loss:  10.386
#  batch error:  11.55
#  batch avg Phy Q value:  5.726
#  batch avg DQN Q value:  6.849
#  batch mean DQN best action probability:  35.704 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.197
# DQN WIS: 2.5
# train
# DQN WDR_: 8.753
# DQN WIS_: 2.5
# ----------
# val
# DQN WDR: -0.63
# DQN WIS: 1.223
# val
# DQN WDR_: 6.594
# DQN WIS_: 1.223
# ----------
# test
# DQN WDR: 3.204
# DQN WIS: 2.499
# test
# DQN WDR_: 9.28
# DQN WIS_: 2.499
# ----------
# ----------
# Saving interim Model 40000
# ----------
# ----------
# Epoch 41000/350000
#  batch loss:  0.093
#  running loss:  10.346
#  batch error:  8.646
#  batch avg Phy Q value:  5.924
#  batch avg DQN Q value:  6.872
#  batch mean DQN best action probability:  35.449 %
# ----------
# Epoch 42000/350000
#  batch loss:  0.095
#  running loss:  10.306
#  batch error:  8.505
#  batch avg Phy Q value:  5.59
#  batch avg DQN Q value:  6.698
#  batch mean DQN best action probability:  32.839 %
# ----------
# Epoch 43000/350000
#  batch loss:  0.072
#  running loss:  10.267
#  batch error:  7.216
#  batch avg Phy Q value:  5.742
#  batch avg DQN Q value:  6.82
#  batch mean DQN best action probability:  35.576 %
# ----------
# Epoch 44000/350000
#  batch loss:  0.117
#  running loss:  10.23
#  batch error:  7.301
#  batch avg Phy Q value:  6.008
#  batch avg DQN Q value:  6.962
#  batch mean DQN best action probability:  33.696 %
# ----------
# Epoch 45000/350000
#  batch loss:  0.101
#  running loss:  10.193
#  batch error:  8.363
#  batch avg Phy Q value:  5.548
#  batch avg DQN Q value:  6.939
#  batch mean DQN best action probability:  35.756 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.256
# DQN WIS: 2.501
# train
# DQN WDR_: 7.03
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: 1.577
# DQN WIS: 2.494
# val
# DQN WDR_: 5.269
# DQN WIS_: 2.494
# ----------
# test
# DQN WDR: 3.322
# DQN WIS: 2.49
# test
# DQN WDR_: 9.417
# DQN WIS_: 2.49
# ----------
# ----------
# Saving interim Model 45000
# ----------
# ----------
# Epoch 46000/350000
#  batch loss:  0.105
#  running loss:  10.155
#  batch error:  8.895
#  batch avg Phy Q value:  5.792
#  batch avg DQN Q value:  6.996
#  batch mean DQN best action probability:  36.188 %
# ----------
# Epoch 47000/350000
#  batch loss:  0.141
#  running loss:  10.119
#  batch error:  9.797
#  batch avg Phy Q value:  5.78
#  batch avg DQN Q value:  6.935
#  batch mean DQN best action probability:  33.399 %
# ----------
# Epoch 48000/350000
#  batch loss:  0.123
#  running loss:  10.082
#  batch error:  9.795
#  batch avg Phy Q value:  5.658
#  batch avg DQN Q value:  7.128
#  batch mean DQN best action probability:  36.524 %
# ----------
# Epoch 49000/350000
#  batch loss:  0.125
#  running loss:  10.049
#  batch error:  9.408
#  batch avg Phy Q value:  6.084
#  batch avg DQN Q value:  6.868
#  batch mean DQN best action probability:  31.847 %
# ----------
# Epoch 50000/350000
#  batch loss:  0.078
#  running loss:  10.016
#  batch error:  7.368
#  batch avg Phy Q value:  6.03
#  batch avg DQN Q value:  6.767
#  batch mean DQN best action probability:  27.408 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.509
# DQN WIS: 2.501
# train
# DQN WDR_: 7.551
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: 0.832
# DQN WIS: 2.492
# val
# DQN WDR_: 7.379
# DQN WIS_: 2.492
# ----------
# test
# DQN WDR: 3.602
# DQN WIS: 2.491
# test
# DQN WDR_: 10.751
# DQN WIS_: 2.491
# ----------
# ----------
# Saving interim Model 50000
# ----------
# ----------
# Epoch 51000/350000
#  batch loss:  0.064
#  running loss:  9.983
#  batch error:  6.022
#  batch avg Phy Q value:  5.787
#  batch avg DQN Q value:  6.969
#  batch mean DQN best action probability:  29.862 %
# ----------
# Epoch 52000/350000
#  batch loss:  0.122
#  running loss:  9.952
#  batch error:  8.623
#  batch avg Phy Q value:  5.817
#  batch avg DQN Q value:  6.855
#  batch mean DQN best action probability:  28.043 %
# ----------
# Epoch 53000/350000
#  batch loss:  0.132
#  running loss:  9.921
#  batch error:  8.944
#  batch avg Phy Q value:  6.014
#  batch avg DQN Q value:  7.055
#  batch mean DQN best action probability:  30.256 %
# ----------
# Epoch 54000/350000
#  batch loss:  0.075
#  running loss:  9.891
#  batch error:  7.016
#  batch avg Phy Q value:  5.661
#  batch avg DQN Q value:  7.22
#  batch mean DQN best action probability:  33.021 %
# ----------
# Epoch 55000/350000
#  batch loss:  0.073
#  running loss:  9.861
#  batch error:  6.523
#  batch avg Phy Q value:  5.907
#  batch avg DQN Q value:  6.915
#  batch mean DQN best action probability:  27.75 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.66
# DQN WIS: 2.5
# train
# DQN WDR_: 6.887
# DQN WIS_: 2.5
# ----------
# val
# DQN WDR: -0.184
# DQN WIS: 1.756
# val
# DQN WDR_: 8.835
# DQN WIS_: 1.756
# ----------
# test
# DQN WDR: 3.657
# DQN WIS: 2.498
# test
# DQN WDR_: 9.659
# DQN WIS_: 2.498
# ----------
# ----------
# Saving interim Model 55000
# ----------
# ----------
# Epoch 56000/350000
#  batch loss:  0.107
#  running loss:  9.831
#  batch error:  8.822
#  batch avg Phy Q value:  5.793
#  batch avg DQN Q value:  7.099
#  batch mean DQN best action probability:  33.463 %
# ----------
# Epoch 57000/350000
#  batch loss:  0.104
#  running loss:  9.802
#  batch error:  7.618
#  batch avg Phy Q value:  6.088
#  batch avg DQN Q value:  7.129
#  batch mean DQN best action probability:  30.787 %
# ----------
# Epoch 58000/350000
#  batch loss:  0.076
#  running loss:  9.772
#  batch error:  7.128
#  batch avg Phy Q value:  5.983
#  batch avg DQN Q value:  7.326
#  batch mean DQN best action probability:  33.174 %
# ----------
# Epoch 59000/350000
#  batch loss:  0.105
#  running loss:  9.741
#  batch error:  8.243
#  batch avg Phy Q value:  6.27
#  batch avg DQN Q value:  7.356
#  batch mean DQN best action probability:  32.666 %
# ----------
# Epoch 60000/350000
#  batch loss:  0.092
#  running loss:  9.712
#  batch error:  8.355
#  batch avg Phy Q value:  6.162
#  batch avg DQN Q value:  7.42
#  batch mean DQN best action probability:  34.189 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.678
# DQN WIS: 2.501
# train
# DQN WDR_: 9.721
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: 0.454
# DQN WIS: 2.403
# val
# DQN WDR_: 8.454
# DQN WIS_: 2.403
# ----------
# test
# DQN WDR: 3.419
# DQN WIS: 2.499
# test
# DQN WDR_: 9.758
# DQN WIS_: 2.499
# ----------
# ----------
# Saving interim Model 60000
# ----------
# ----------
# Epoch 61000/350000
#  batch loss:  0.097
#  running loss:  9.686
#  batch error:  7.652
#  batch avg Phy Q value:  6.287
#  batch avg DQN Q value:  7.323
#  batch mean DQN best action probability:  30.721 %
# ----------
# Epoch 62000/350000
#  batch loss:  0.051
#  running loss:  9.658
#  batch error:  6.154
#  batch avg Phy Q value:  6.466
#  batch avg DQN Q value:  7.383
#  batch mean DQN best action probability:  32.81 %
# ----------
# Epoch 63000/350000
#  batch loss:  0.121
#  running loss:  9.631
#  batch error:  9.156
#  batch avg Phy Q value:  5.833
#  batch avg DQN Q value:  7.132
#  batch mean DQN best action probability:  27.974 %
# ----------
# Epoch 64000/350000
#  batch loss:  0.098
#  running loss:  9.606
#  batch error:  8.588
#  batch avg Phy Q value:  5.941
#  batch avg DQN Q value:  7.296
#  batch mean DQN best action probability:  32.813 %
# ----------
# Epoch 65000/350000
#  batch loss:  0.111
#  running loss:  9.58
#  batch error:  8.413
#  batch avg Phy Q value:  6.48
#  batch avg DQN Q value:  7.445
#  batch mean DQN best action probability:  32.477 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.673
# DQN WIS: 2.501
# train
# DQN WDR_: 9.1
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: 0.864
# DQN WIS: 2.479
# val
# DQN WDR_: 8.52
# DQN WIS_: 2.479
# ----------
# test
# DQN WDR: 3.236
# DQN WIS: 2.481
# test
# DQN WDR_: 9.145
# DQN WIS_: 2.481
# ----------
# ----------
# Saving interim Model 65000
# ----------
# ----------
# Epoch 66000/350000
#  batch loss:  0.059
#  running loss:  9.553
#  batch error:  6.23
#  batch avg Phy Q value:  5.845
#  batch avg DQN Q value:  7.691
#  batch mean DQN best action probability:  36.189 %
# ----------
# Epoch 67000/350000
#  batch loss:  0.086
#  running loss:  9.526
#  batch error:  7.306
#  batch avg Phy Q value:  6.123
#  batch avg DQN Q value:  7.441
#  batch mean DQN best action probability:  33.173 %
# ----------
# Epoch 68000/350000
#  batch loss:  0.107
#  running loss:  9.501
#  batch error:  8.393
#  batch avg Phy Q value:  6.28
#  batch avg DQN Q value:  7.329
#  batch mean DQN best action probability:  29.735 %
# ----------
# Epoch 69000/350000
#  batch loss:  0.065
#  running loss:  9.474
#  batch error:  6.258
#  batch avg Phy Q value:  6.517
#  batch avg DQN Q value:  7.626
#  batch mean DQN best action probability:  33.005 %
# ----------
# Epoch 70000/350000
#  batch loss:  0.052
#  running loss:  9.448
#  batch error:  5.945
#  batch avg Phy Q value:  6.638
#  batch avg DQN Q value:  7.395
#  batch mean DQN best action probability:  30.282 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.427
# DQN WIS: 2.497
# train
# DQN WDR_: 9.708
# DQN WIS_: 2.497
# ----------
# val
# DQN WDR: 1.235
# DQN WIS: 2.238
# val
# DQN WDR_: 6.423
# DQN WIS_: 2.238
# ----------
# test
# DQN WDR: 3.35
# DQN WIS: 2.501
# test
# DQN WDR_: 9.137
# DQN WIS_: 2.501
# ----------
# ----------
# Saving interim Model 70000
# ----------
# ----------
# Epoch 71000/350000
#  batch loss:  0.124
#  running loss:  9.423
#  batch error:  9.002
#  batch avg Phy Q value:  6.415
#  batch avg DQN Q value:  7.413
#  batch mean DQN best action probability:  31.617 %
# ----------
# Epoch 72000/350000
#  batch loss:  0.098
#  running loss:  9.398
#  batch error:  7.303
#  batch avg Phy Q value:  6.298
#  batch avg DQN Q value:  7.607
#  batch mean DQN best action probability:  34.264 %
# ----------
# Epoch 73000/350000
#  batch loss:  0.083
#  running loss:  9.374
#  batch error:  7.575
#  batch avg Phy Q value:  6.358
#  batch avg DQN Q value:  7.701
#  batch mean DQN best action probability:  34.363 %
# ----------
# Epoch 74000/350000
#  batch loss:  0.088
#  running loss:  9.35
#  batch error:  8.214
#  batch avg Phy Q value:  6.387
#  batch avg DQN Q value:  7.543
#  batch mean DQN best action probability:  31.962 %
# ----------
# Epoch 75000/350000
#  batch loss:  0.059
#  running loss:  9.326
#  batch error:  5.996
#  batch avg Phy Q value:  6.192
#  batch avg DQN Q value:  7.494
#  batch mean DQN best action probability:  29.571 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.119
# DQN WIS: 2.499
# train
# DQN WDR_: 9.626
# DQN WIS_: 2.499
# ----------
# val
# DQN WDR: 1.835
# DQN WIS: 2.499
# val
# DQN WDR_: 5.688
# DQN WIS_: 2.499
# ----------
# test
# DQN WDR: 3.093
# DQN WIS: 2.502
# test
# DQN WDR_: 8.345
# DQN WIS_: 2.502
# ----------
# ----------
# Saving interim Model 75000
# ----------
# ----------
# Epoch 76000/350000
#  batch loss:  0.095
#  running loss:  9.304
#  batch error:  7.62
#  batch avg Phy Q value:  5.952
#  batch avg DQN Q value:  7.728
#  batch mean DQN best action probability:  35.066 %
# ----------
# Epoch 77000/350000
#  batch loss:  0.131
#  running loss:  9.281
#  batch error:  9.421
#  batch avg Phy Q value:  6.495
#  batch avg DQN Q value:  7.617
#  batch mean DQN best action probability:  32.827 %
# ----------
# Epoch 78000/350000
#  batch loss:  0.077
#  running loss:  9.258
#  batch error:  7.144
#  batch avg Phy Q value:  6.522
#  batch avg DQN Q value:  7.806
#  batch mean DQN best action probability:  33.882 %
# ----------
# Epoch 79000/350000
#  batch loss:  0.056
#  running loss:  9.235
#  batch error:  5.908
#  batch avg Phy Q value:  6.766
#  batch avg DQN Q value:  8.107
#  batch mean DQN best action probability:  37.745 %
# ----------
# Epoch 80000/350000
#  batch loss:  0.132
#  running loss:  9.212
#  batch error:  7.206
#  batch avg Phy Q value:  6.709
#  batch avg DQN Q value:  7.73
#  batch mean DQN best action probability:  35.146 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.002
# DQN WIS: 2.501
# train
# DQN WDR_: 9.498
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: 1.959
# DQN WIS: 2.486
# val
# DQN WDR_: 5.505
# DQN WIS_: 2.486
# ----------
# test
# DQN WDR: 3.377
# DQN WIS: 2.501
# test
# DQN WDR_: 9.638
# DQN WIS_: 2.501
# ----------
# ----------
# Saving interim Model 80000
# ----------
# ----------
# Epoch 81000/350000
#  batch loss:  0.072
#  running loss:  9.19
#  batch error:  6.81
#  batch avg Phy Q value:  6.78
#  batch avg DQN Q value:  7.678
#  batch mean DQN best action probability:  32.353 %
# ----------
# Epoch 82000/350000
#  batch loss:  0.094
#  running loss:  9.168
#  batch error:  7.496
#  batch avg Phy Q value:  6.555
#  batch avg DQN Q value:  7.668
#  batch mean DQN best action probability:  31.976 %
# ----------
# Epoch 83000/350000
#  batch loss:  0.075
#  running loss:  9.145
#  batch error:  6.707
#  batch avg Phy Q value:  6.526
#  batch avg DQN Q value:  7.678
#  batch mean DQN best action probability:  29.681 %
# ----------
# Epoch 84000/350000
#  batch loss:  0.09
#  running loss:  9.123
#  batch error:  7.574
#  batch avg Phy Q value:  6.788
#  batch avg DQN Q value:  7.806
#  batch mean DQN best action probability:  30.806 %
# ----------
# Epoch 85000/350000
#  batch loss:  0.096
#  running loss:  9.102
#  batch error:  7.571
#  batch avg Phy Q value:  6.942
#  batch avg DQN Q value:  7.759
#  batch mean DQN best action probability:  32.457 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.42
# DQN WIS: 2.496
# train
# DQN WDR_: 9.66
# DQN WIS_: 2.496
# ----------
# val
# DQN WDR: 1.729
# DQN WIS: 2.488
# val
# DQN WDR_: 6.955
# DQN WIS_: 2.488
# ----------
# test
# DQN WDR: 3.288
# DQN WIS: 2.502
# test
# DQN WDR_: 8.02
# DQN WIS_: 2.502
# ----------
# ----------
# Saving interim Model 85000
# ----------
# ----------
# Epoch 86000/350000
#  batch loss:  0.084
#  running loss:  9.081
#  batch error:  7.537
#  batch avg Phy Q value:  6.776
#  batch avg DQN Q value:  7.788
#  batch mean DQN best action probability:  30.906 %
# ----------
# Epoch 87000/350000
#  batch loss:  0.086
#  running loss:  9.059
#  batch error:  7.419
#  batch avg Phy Q value:  6.95
#  batch avg DQN Q value:  7.805
#  batch mean DQN best action probability:  31.996 %
# ----------
# Epoch 88000/350000
#  batch loss:  0.064
#  running loss:  9.037
#  batch error:  6.401
#  batch avg Phy Q value:  6.882
#  batch avg DQN Q value:  8.164
#  batch mean DQN best action probability:  33.56 %
# ----------
# Epoch 89000/350000
#  batch loss:  0.112
#  running loss:  9.017
#  batch error:  8.011
#  batch avg Phy Q value:  6.66
#  batch avg DQN Q value:  7.837
#  batch mean DQN best action probability:  29.85 %
# ----------
# Epoch 90000/350000
#  batch loss:  0.064
#  running loss:  8.996
#  batch error:  5.819
#  batch avg Phy Q value:  6.403
#  batch avg DQN Q value:  7.917
#  batch mean DQN best action probability:  32.185 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.35
# DQN WIS: 2.5
# train
# DQN WDR_: 9.773
# DQN WIS_: 2.5
# ----------
# val
# DQN WDR: -0.076
# DQN WIS: 0.218
# val
# DQN WDR_: 5.507
# DQN WIS_: 0.218
# ----------
# test
# DQN WDR: 3.163
# DQN WIS: 2.501
# test
# DQN WDR_: 6.565
# DQN WIS_: 2.501
# ----------
# ----------
# Saving interim Model 90000
# ----------
# ----------
# Epoch 91000/350000
#  batch loss:  0.066
#  running loss:  8.975
#  batch error:  6.261
#  batch avg Phy Q value:  6.743
#  batch avg DQN Q value:  7.875
#  batch mean DQN best action probability:  32.423 %
# ----------
# Epoch 92000/350000
#  batch loss:  0.076
#  running loss:  8.955
#  batch error:  7.316
#  batch avg Phy Q value:  6.685
#  batch avg DQN Q value:  7.913
#  batch mean DQN best action probability:  31.605 %
# ----------
# Epoch 93000/350000
#  batch loss:  0.093
#  running loss:  8.935
#  batch error:  7.378
#  batch avg Phy Q value:  6.448
#  batch avg DQN Q value:  7.676
#  batch mean DQN best action probability:  30.608 %
# ----------
# Epoch 94000/350000
#  batch loss:  0.071
#  running loss:  8.915
#  batch error:  6.806
#  batch avg Phy Q value:  6.659
#  batch avg DQN Q value:  7.854
#  batch mean DQN best action probability:  33.679 %
# ----------
# Epoch 95000/350000
#  batch loss:  0.087
#  running loss:  8.894
#  batch error:  6.788
#  batch avg Phy Q value:  6.907
#  batch avg DQN Q value:  7.684
#  batch mean DQN best action probability:  29.945 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.497
# DQN WIS: 2.499
# train
# DQN WDR_: 9.368
# DQN WIS_: 2.499
# ----------
# val
# DQN WDR: 0.587
# DQN WIS: 1.154
# val
# DQN WDR_: 7.288
# DQN WIS_: 1.154
# ----------
# test
# DQN WDR: 2.95
# DQN WIS: 2.502
# test
# DQN WDR_: 7.88
# DQN WIS_: 2.502
# ----------
# ----------
# Saving interim Model 95000
# ----------
# ----------
# Epoch 96000/350000
#  batch loss:  0.092
#  running loss:  8.875
#  batch error:  7.198
#  batch avg Phy Q value:  6.655
#  batch avg DQN Q value:  7.807
#  batch mean DQN best action probability:  31.525 %
# ----------
# Epoch 97000/350000
#  batch loss:  0.085
#  running loss:  8.855
#  batch error:  6.436
#  batch avg Phy Q value:  6.783
#  batch avg DQN Q value:  8.109
#  batch mean DQN best action probability:  38.205 %
# ----------
# Epoch 98000/350000
#  batch loss:  0.071
#  running loss:  8.835
#  batch error:  6.112
#  batch avg Phy Q value:  6.717
#  batch avg DQN Q value:  7.863
#  batch mean DQN best action probability:  29.921 %
# ----------
# Epoch 99000/350000
#  batch loss:  0.105
#  running loss:  8.815
#  batch error:  7.967
#  batch avg Phy Q value:  6.686
#  batch avg DQN Q value:  7.994
#  batch mean DQN best action probability:  33.844 %
# ----------
# Epoch 100000/350000
#  batch loss:  0.107
#  running loss:  8.796
#  batch error:  7.443
#  batch avg Phy Q value:  6.724
#  batch avg DQN Q value:  7.885
#  batch mean DQN best action probability:  30.587 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.637
# DQN WIS: 2.499
# train
# DQN WDR_: 8.386
# DQN WIS_: 2.499
# ----------
# val
# DQN WDR: 0.751
# DQN WIS: 1.858
# val
# DQN WDR_: 8.585
# DQN WIS_: 1.858
# ----------
# test
# DQN WDR: 2.873
# DQN WIS: 2.498
# test
# DQN WDR_: 8.021
# DQN WIS_: 2.498
# ----------
# ----------
# Saving interim Model 100000
# ----------
# ----------
# Epoch 101000/350000
#  batch loss:  0.104
#  running loss:  8.776
#  batch error:  7.247
#  batch avg Phy Q value:  6.572
#  batch avg DQN Q value:  8.085
#  batch mean DQN best action probability:  31.732 %
# ----------
# Epoch 102000/350000
#  batch loss:  0.118
#  running loss:  8.756
#  batch error:  7.787
#  batch avg Phy Q value:  7.121
#  batch avg DQN Q value:  8.221
#  batch mean DQN best action probability:  34.563 %
# ----------
# Epoch 103000/350000
#  batch loss:  0.067
#  running loss:  8.737
#  batch error:  6.914
#  batch avg Phy Q value:  6.943
#  batch avg DQN Q value:  7.874
#  batch mean DQN best action probability:  28.788 %
# ----------
# Epoch 104000/350000
#  batch loss:  0.082
#  running loss:  8.719
#  batch error:  7.087
#  batch avg Phy Q value:  6.502
#  batch avg DQN Q value:  7.922
#  batch mean DQN best action probability:  29.503 %
# ----------
# Epoch 105000/350000
#  batch loss:  0.063
#  running loss:  8.7
#  batch error:  6.147
#  batch avg Phy Q value:  6.436
#  batch avg DQN Q value:  7.984
#  batch mean DQN best action probability:  31.898 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.792
# DQN WIS: 2.501
# train
# DQN WDR_: 6.721
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: 1.855
# DQN WIS: 2.252
# val
# DQN WDR_: 7.252
# DQN WIS_: 2.252
# ----------
# test
# DQN WDR: 2.465
# DQN WIS: 2.493
# test
# DQN WDR_: 7.395
# DQN WIS_: 2.493
# ----------
# ----------
# Saving interim Model 105000
# ----------
# ----------
# Epoch 106000/350000
#  batch loss:  0.098
#  running loss:  8.682
#  batch error:  7.472
#  batch avg Phy Q value:  6.631
#  batch avg DQN Q value:  7.894
#  batch mean DQN best action probability:  31.279 %
# ----------
# Epoch 107000/350000
#  batch loss:  0.055
#  running loss:  8.666
#  batch error:  5.746
#  batch avg Phy Q value:  6.444
#  batch avg DQN Q value:  7.916
#  batch mean DQN best action probability:  30.13 %
# ----------
# Epoch 108000/350000
#  batch loss:  0.162
#  running loss:  8.648
#  batch error:  6.917
#  batch avg Phy Q value:  6.775
#  batch avg DQN Q value:  7.889
#  batch mean DQN best action probability:  29.686 %
# ----------
# Epoch 109000/350000
#  batch loss:  0.068
#  running loss:  8.63
#  batch error:  5.447
#  batch avg Phy Q value:  7.135
#  batch avg DQN Q value:  8.218
#  batch mean DQN best action probability:  32.347 %
# ----------
# Epoch 110000/350000
#  batch loss:  0.065
#  running loss:  8.613
#  batch error:  5.908
#  batch avg Phy Q value:  6.766
#  batch avg DQN Q value:  8.121
#  batch mean DQN best action probability:  33.164 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.771
# DQN WIS: 2.501
# train
# DQN WDR_: 8.582
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: 0.676
# DQN WIS: 2.184
# val
# DQN WDR_: 9.77
# DQN WIS_: 2.184
# ----------
# test
# DQN WDR: 3.107
# DQN WIS: 2.496
# test
# DQN WDR_: 8.058
# DQN WIS_: 2.496
# ----------
# ----------
# Saving interim Model 110000
# ----------
# ----------
# Epoch 111000/350000
#  batch loss:  0.072
#  running loss:  8.596
#  batch error:  6.624
#  batch avg Phy Q value:  6.831
#  batch avg DQN Q value:  8.278
#  batch mean DQN best action probability:  34.518 %
# ----------
# Epoch 112000/350000
#  batch loss:  0.059
#  running loss:  8.579
#  batch error:  5.809
#  batch avg Phy Q value:  6.626
#  batch avg DQN Q value:  7.926
#  batch mean DQN best action probability:  27.92 %
# ----------
# Epoch 113000/350000
#  batch loss:  0.059
#  running loss:  8.562
#  batch error:  5.662
#  batch avg Phy Q value:  6.689
#  batch avg DQN Q value:  7.93
#  batch mean DQN best action probability:  27.011 %
# ----------
# Epoch 114000/350000
#  batch loss:  0.074
#  running loss:  8.544
#  batch error:  6.172
#  batch avg Phy Q value:  6.922
#  batch avg DQN Q value:  8.064
#  batch mean DQN best action probability:  30.452 %
# ----------
# Epoch 115000/350000
#  batch loss:  0.081
#  running loss:  8.526
#  batch error:  6.259
#  batch avg Phy Q value:  6.78
#  batch avg DQN Q value:  7.998
#  batch mean DQN best action probability:  28.323 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.778
# DQN WIS: 2.501
# train
# DQN WDR_: 9.202
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: -1.549
# DQN WIS: -1.258
# val
# DQN WDR_: 5.513
# DQN WIS_: -1.258
# ----------
# test
# DQN WDR: 3.4
# DQN WIS: 2.49
# test
# DQN WDR_: 9.424
# DQN WIS_: 2.49
# ----------
# ----------
# Saving interim Model 115000
# ----------
# ----------
# Epoch 116000/350000
#  batch loss:  0.099
#  running loss:  8.509
#  batch error:  6.379
#  batch avg Phy Q value:  7.03
#  batch avg DQN Q value:  8.178
#  batch mean DQN best action probability:  27.992 %
# ----------
# Epoch 117000/350000
#  batch loss:  0.065
#  running loss:  8.492
#  batch error:  5.884
#  batch avg Phy Q value:  7.196
#  batch avg DQN Q value:  8.189
#  batch mean DQN best action probability:  29.504 %
# ----------
# Epoch 118000/350000
#  batch loss:  0.088
#  running loss:  8.476
#  batch error:  6.895
#  batch avg Phy Q value:  7.001
#  batch avg DQN Q value:  8.327
#  batch mean DQN best action probability:  30.636 %
# ----------
# Epoch 119000/350000
#  batch loss:  0.081
#  running loss:  8.46
#  batch error:  6.823
#  batch avg Phy Q value:  6.931
#  batch avg DQN Q value:  8.153
#  batch mean DQN best action probability:  27.734 %
# ----------
# Epoch 120000/350000
#  batch loss:  0.09
#  running loss:  8.443
#  batch error:  6.921
#  batch avg Phy Q value:  6.932
#  batch avg DQN Q value:  8.267
#  batch mean DQN best action probability:  30.111 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.741
# DQN WIS: 2.499
# train
# DQN WDR_: 9.081
# DQN WIS_: 2.499
# ----------
# val
# DQN WDR: -0.748
# DQN WIS: 0.042
# val
# DQN WDR_: 7.501
# DQN WIS_: 0.042
# ----------
# test
# DQN WDR: 3.341
# DQN WIS: 2.501
# test
# DQN WDR_: 7.951
# DQN WIS_: 2.501
# ----------
# ----------
# Saving interim Model 120000
# ----------
# ----------
# Epoch 121000/350000
#  batch loss:  0.068
#  running loss:  8.427
#  batch error:  6.026
#  batch avg Phy Q value:  7.096
#  batch avg DQN Q value:  8.421
#  batch mean DQN best action probability:  29.835 %
# ----------
# Epoch 122000/350000
#  batch loss:  0.074
#  running loss:  8.411
#  batch error:  6.081
#  batch avg Phy Q value:  7.528
#  batch avg DQN Q value:  8.496
#  batch mean DQN best action probability:  30.947 %
# ----------
# Epoch 123000/350000
#  batch loss:  0.066
#  running loss:  8.394
#  batch error:  5.783
#  batch avg Phy Q value:  7.044
#  batch avg DQN Q value:  8.375
#  batch mean DQN best action probability:  28.606 %
# ----------
# Epoch 124000/350000
#  batch loss:  0.118
#  running loss:  8.378
#  batch error:  8.774
#  batch avg Phy Q value:  7.099
#  batch avg DQN Q value:  8.547
#  batch mean DQN best action probability:  31.098 %
# ----------
# Epoch 125000/350000
#  batch loss:  0.134
#  running loss:  8.361
#  batch error:  4.572
#  batch avg Phy Q value:  7.232
#  batch avg DQN Q value:  8.531
#  batch mean DQN best action probability:  32.519 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.603
# DQN WIS: 2.501
# train
# DQN WDR_: 8.451
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: -0.422
# DQN WIS: 2.184
# val
# DQN WDR_: 9.842
# DQN WIS_: 2.184
# ----------
# test
# DQN WDR: 3.326
# DQN WIS: 2.5
# test
# DQN WDR_: 8.61
# DQN WIS_: 2.5
# ----------
# ----------
# Saving interim Model 125000
# ----------
# ----------
# Epoch 126000/350000
#  batch loss:  0.092
#  running loss:  8.345
#  batch error:  6.966
#  batch avg Phy Q value:  7.256
#  batch avg DQN Q value:  8.388
#  batch mean DQN best action probability:  29.165 %
# ----------
# Epoch 127000/350000
#  batch loss:  0.06
#  running loss:  8.329
#  batch error:  5.758
#  batch avg Phy Q value:  7.356
#  batch avg DQN Q value:  8.588
#  batch mean DQN best action probability:  31.666 %
# ----------
# Epoch 128000/350000
#  batch loss:  0.093
#  running loss:  8.313
#  batch error:  6.893
#  batch avg Phy Q value:  7.286
#  batch avg DQN Q value:  8.394
#  batch mean DQN best action probability:  31.41 %
# ----------
# Epoch 129000/350000
#  batch loss:  0.097
#  running loss:  8.297
#  batch error:  7.319
#  batch avg Phy Q value:  7.422
#  batch avg DQN Q value:  8.586
#  batch mean DQN best action probability:  30.341 %
# ----------
# Epoch 130000/350000
#  batch loss:  0.069
#  running loss:  8.282
#  batch error:  6.539
#  batch avg Phy Q value:  7.081
#  batch avg DQN Q value:  8.702
#  batch mean DQN best action probability:  34.016 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.647
# DQN WIS: 2.5
# train
# DQN WDR_: 7.827
# DQN WIS_: 2.5
# ----------
# val
# DQN WDR: -0.139
# DQN WIS: 2.406
# val
# DQN WDR_: 8.06
# DQN WIS_: 2.406
# ----------
# test
# DQN WDR: 2.954
# DQN WIS: 2.5
# test
# DQN WDR_: 7.849
# DQN WIS_: 2.5
# ----------
# ----------
# Saving interim Model 130000
# ----------
# ----------
# Epoch 131000/350000
#  batch loss:  0.106
#  running loss:  8.266
#  batch error:  7.138
#  batch avg Phy Q value:  7.575
#  batch avg DQN Q value:  8.441
#  batch mean DQN best action probability:  26.718 %
# ----------
# Epoch 132000/350000
#  batch loss:  0.069
#  running loss:  8.251
#  batch error:  5.846
#  batch avg Phy Q value:  7.421
#  batch avg DQN Q value:  8.475
#  batch mean DQN best action probability:  27.737 %
# ----------
# Epoch 133000/350000
#  batch loss:  0.07
#  running loss:  8.236
#  batch error:  5.858
#  batch avg Phy Q value:  7.124
#  batch avg DQN Q value:  8.511
#  batch mean DQN best action probability:  31.044 %
# ----------
# Epoch 134000/350000
#  batch loss:  0.076
#  running loss:  8.22
#  batch error:  6.354
#  batch avg Phy Q value:  7.235
#  batch avg DQN Q value:  8.977
#  batch mean DQN best action probability:  36.047 %
# ----------
# Epoch 135000/350000
#  batch loss:  0.069
#  running loss:  8.205
#  batch error:  5.92
#  batch avg Phy Q value:  7.612
#  batch avg DQN Q value:  8.633
#  batch mean DQN best action probability:  32.183 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.758
# DQN WIS: 2.502
# train
# DQN WDR_: 6.734
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 2.167
# DQN WIS: 2.133
# val
# DQN WDR_: 6.452
# DQN WIS_: 2.133
# ----------
# test
# DQN WDR: 2.784
# DQN WIS: 2.477
# test
# DQN WDR_: 7.876
# DQN WIS_: 2.477
# ----------
# ----------
# Saving interim Model 135000
# ----------
# ----------
# Epoch 136000/350000
#  batch loss:  0.073
#  running loss:  8.19
#  batch error:  6.416
#  batch avg Phy Q value:  7.331
#  batch avg DQN Q value:  8.628
#  batch mean DQN best action probability:  32.118 %
# ----------
# Epoch 137000/350000
#  batch loss:  0.08
#  running loss:  8.176
#  batch error:  5.977
#  batch avg Phy Q value:  7.327
#  batch avg DQN Q value:  8.486
#  batch mean DQN best action probability:  30.703 %
# ----------
# Epoch 138000/350000
#  batch loss:  0.052
#  running loss:  8.161
#  batch error:  5.936
#  batch avg Phy Q value:  7.676
#  batch avg DQN Q value:  8.514
#  batch mean DQN best action probability:  29.469 %
# ----------
# Epoch 139000/350000
#  batch loss:  0.082
#  running loss:  8.147
#  batch error:  6.807
#  batch avg Phy Q value:  7.599
#  batch avg DQN Q value:  8.402
#  batch mean DQN best action probability:  27.351 %
# ----------
# Epoch 140000/350000
#  batch loss:  0.076
#  running loss:  8.132
#  batch error:  5.835
#  batch avg Phy Q value:  7.302
#  batch avg DQN Q value:  8.612
#  batch mean DQN best action probability:  34.375 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.671
# DQN WIS: 2.5
# train
# DQN WDR_: 8.504
# DQN WIS_: 2.5
# ----------
# val
# DQN WDR: 1.098
# DQN WIS: 2.119
# val
# DQN WDR_: 8.435
# DQN WIS_: 2.119
# ----------
# test
# DQN WDR: 2.973
# DQN WIS: 2.496
# test
# DQN WDR_: 7.811
# DQN WIS_: 2.496
# ----------
# ----------
# Saving interim Model 140000
# ----------
# ----------
# Epoch 141000/350000
#  batch loss:  0.089
#  running loss:  8.118
#  batch error:  6.85
#  batch avg Phy Q value:  7.33
#  batch avg DQN Q value:  8.657
#  batch mean DQN best action probability:  31.412 %
# ----------
# Epoch 142000/350000
#  batch loss:  0.1
#  running loss:  8.104
#  batch error:  5.665
#  batch avg Phy Q value:  7.391
#  batch avg DQN Q value:  8.452
#  batch mean DQN best action probability:  29.358 %
# ----------
# Epoch 143000/350000
#  batch loss:  0.046
#  running loss:  8.089
#  batch error:  4.736
#  batch avg Phy Q value:  7.461
#  batch avg DQN Q value:  8.497
#  batch mean DQN best action probability:  29.613 %
# ----------
# Epoch 144000/350000
#  batch loss:  0.035
#  running loss:  8.075
#  batch error:  3.94
#  batch avg Phy Q value:  7.705
#  batch avg DQN Q value:  8.942
#  batch mean DQN best action probability:  36.88 %
# ----------
# Epoch 145000/350000
#  batch loss:  0.043
#  running loss:  8.06
#  batch error:  4.687
#  batch avg Phy Q value:  7.429
#  batch avg DQN Q value:  8.603
#  batch mean DQN best action probability:  30.669 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.658
# DQN WIS: 2.5
# train
# DQN WDR_: 8.443
# DQN WIS_: 2.5
# ----------
# val
# DQN WDR: 1.532
# DQN WIS: 2.42
# val
# DQN WDR_: 7.706
# DQN WIS_: 2.42
# ----------
# test
# DQN WDR: 2.705
# DQN WIS: 2.38
# test
# DQN WDR_: 7.599
# DQN WIS_: 2.38
# ----------
# ----------
# Saving interim Model 145000
# ----------
# ----------
# Epoch 146000/350000
#  batch loss:  0.184
#  running loss:  8.047
#  batch error:  5.979
#  batch avg Phy Q value:  7.533
#  batch avg DQN Q value:  8.632
#  batch mean DQN best action probability:  30.108 %
# ----------
# Epoch 147000/350000
#  batch loss:  0.055
#  running loss:  8.033
#  batch error:  3.695
#  batch avg Phy Q value:  7.586
#  batch avg DQN Q value:  8.782
#  batch mean DQN best action probability:  32.551 %
# ----------
# Epoch 148000/350000
#  batch loss:  0.059
#  running loss:  8.019
#  batch error:  6.127
#  batch avg Phy Q value:  7.64
#  batch avg DQN Q value:  8.742
#  batch mean DQN best action probability:  32.979 %
# ----------
# Epoch 149000/350000
#  batch loss:  0.072
#  running loss:  8.004
#  batch error:  5.79
#  batch avg Phy Q value:  7.359
#  batch avg DQN Q value:  8.58
#  batch mean DQN best action probability:  28.259 %
# ----------
# Epoch 150000/350000
#  batch loss:  0.054
#  running loss:  7.991
#  batch error:  5.135
#  batch avg Phy Q value:  6.963
#  batch avg DQN Q value:  8.528
#  batch mean DQN best action probability:  30.126 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.712
# DQN WIS: 2.5
# train
# DQN WDR_: 8.335
# DQN WIS_: 2.5
# ----------
# val
# DQN WDR: -0.054
# DQN WIS: -0.008
# val
# DQN WDR_: 5.92
# DQN WIS_: -0.008
# ----------
# test
# DQN WDR: 2.622
# DQN WIS: 2.447
# test
# DQN WDR_: 6.677
# DQN WIS_: 2.447
# ----------
# ----------
# Saving interim Model 150000
# ----------
# ----------
# Epoch 151000/350000
#  batch loss:  0.068
#  running loss:  7.977
#  batch error:  5.525
#  batch avg Phy Q value:  7.355
#  batch avg DQN Q value:  8.828
#  batch mean DQN best action probability:  33.313 %
# ----------
# Epoch 152000/350000
#  batch loss:  0.079
#  running loss:  7.963
#  batch error:  6.811
#  batch avg Phy Q value:  7.554
#  batch avg DQN Q value:  8.659
#  batch mean DQN best action probability:  29.081 %
# ----------
# Epoch 153000/350000
#  batch loss:  0.128
#  running loss:  7.95
#  batch error:  8.315
#  batch avg Phy Q value:  7.529
#  batch avg DQN Q value:  8.603
#  batch mean DQN best action probability:  28.971 %
# ----------
# Epoch 154000/350000
#  batch loss:  0.099
#  running loss:  7.935
#  batch error:  7.512
#  batch avg Phy Q value:  7.179
#  batch avg DQN Q value:  8.945
#  batch mean DQN best action probability:  33.92 %
# ----------
# Epoch 155000/350000
#  batch loss:  0.055
#  running loss:  7.922
#  batch error:  5.531
#  batch avg Phy Q value:  7.417
#  batch avg DQN Q value:  8.923
#  batch mean DQN best action probability:  31.407 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.033
# DQN WIS: 2.501
# train
# DQN WDR_: 7.292
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: -0.253
# DQN WIS: -0.832
# val
# DQN WDR_: 6.05
# DQN WIS_: -0.832
# ----------
# test
# DQN WDR: 2.838
# DQN WIS: 2.455
# test
# DQN WDR_: 8.204
# DQN WIS_: 2.455
# ----------
# ----------
# Saving interim Model 155000
# ----------
# ----------
# Epoch 156000/350000
#  batch loss:  0.065
#  running loss:  7.909
#  batch error:  5.595
#  batch avg Phy Q value:  7.806
#  batch avg DQN Q value:  8.897
#  batch mean DQN best action probability:  30.261 %
# ----------
# Epoch 157000/350000
#  batch loss:  0.038
#  running loss:  7.895
#  batch error:  4.35
#  batch avg Phy Q value:  7.586
#  batch avg DQN Q value:  8.704
#  batch mean DQN best action probability:  28.976 %
# ----------
# Epoch 158000/350000
#  batch loss:  0.046
#  running loss:  7.881
#  batch error:  4.155
#  batch avg Phy Q value:  7.395
#  batch avg DQN Q value:  8.731
#  batch mean DQN best action probability:  28.462 %
# ----------
# Epoch 159000/350000
#  batch loss:  0.052
#  running loss:  7.867
#  batch error:  4.749
#  batch avg Phy Q value:  8.054
#  batch avg DQN Q value:  9.091
#  batch mean DQN best action probability:  31.872 %
# ----------
# Epoch 160000/350000
#  batch loss:  0.038
#  running loss:  7.854
#  batch error:  4.717
#  batch avg Phy Q value:  7.945
#  batch avg DQN Q value:  9.099
#  batch mean DQN best action probability:  31.877 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -0.29
# DQN WIS: 2.501
# train
# DQN WDR_: 7.791
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: 0.155
# DQN WIS: -0.092
# val
# DQN WDR_: 6.955
# DQN WIS_: -0.092
# ----------
# test
# DQN WDR: 2.673
# DQN WIS: 2.428
# test
# DQN WDR_: 7.778
# DQN WIS_: 2.428
# ----------
# ----------
# Saving interim Model 160000
# ----------
# ----------
# Epoch 161000/350000
#  batch loss:  0.039
#  running loss:  7.84
#  batch error:  4.402
#  batch avg Phy Q value:  7.703
#  batch avg DQN Q value:  8.96
#  batch mean DQN best action probability:  28.815 %
# ----------
# Epoch 162000/350000
#  batch loss:  0.076
#  running loss:  7.827
#  batch error:  6.302
#  batch avg Phy Q value:  7.232
#  batch avg DQN Q value:  8.975
#  batch mean DQN best action probability:  30.78 %
# ----------
# Epoch 163000/350000
#  batch loss:  0.049
#  running loss:  7.813
#  batch error:  4.984
#  batch avg Phy Q value:  8.215
#  batch avg DQN Q value:  9.298
#  batch mean DQN best action probability:  33.666 %
# ----------
# Epoch 164000/350000
#  batch loss:  0.074
#  running loss:  7.801
#  batch error:  5.774
#  batch avg Phy Q value:  7.973
#  batch avg DQN Q value:  9.09
#  batch mean DQN best action probability:  31.763 %
# ----------
# Epoch 165000/350000
#  batch loss:  0.097
#  running loss:  7.788
#  batch error:  7.049
#  batch avg Phy Q value:  7.907
#  batch avg DQN Q value:  9.401
#  batch mean DQN best action probability:  33.799 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.075
# DQN WIS: 2.501
# train
# DQN WDR_: 8.962
# DQN WIS_: 2.501
# ----------
# val
# DQN WDR: -0.714
# DQN WIS: -0.02
# val
# DQN WDR_: 7.779
# DQN WIS_: -0.02
# ----------
# test
# DQN WDR: 2.599
# DQN WIS: 2.466
# test
# DQN WDR_: 7.601
# DQN WIS_: 2.466
# ----------
# ----------
# Saving interim Model 165000
# ----------
# ----------
# Epoch 166000/350000
#  batch loss:  0.137
#  running loss:  7.775
#  batch error:  8.172
#  batch avg Phy Q value:  7.687
#  batch avg DQN Q value:  9.063
#  batch mean DQN best action probability:  30.398 %
# ----------
# Epoch 167000/350000
#  batch loss:  0.078
#  running loss:  7.762
#  batch error:  6.559
#  batch avg Phy Q value:  7.677
#  batch avg DQN Q value:  8.994
#  batch mean DQN best action probability:  28.581 %
# ----------
# Epoch 168000/350000
#  batch loss:  0.042
#  running loss:  7.749
#  batch error:  4.158
#  batch avg Phy Q value:  8.001
#  batch avg DQN Q value:  9.461
#  batch mean DQN best action probability:  33.961 %
# ----------
# Epoch 169000/350000
#  batch loss:  0.052
#  running loss:  7.736
#  batch error:  4.946
#  batch avg Phy Q value:  8.211
#  batch avg DQN Q value:  9.416
#  batch mean DQN best action probability:  32.741 %
# ----------
# Epoch 170000/350000
#  batch loss:  0.071
#  running loss:  7.724
#  batch error:  6.031
#  batch avg Phy Q value:  7.602
#  batch avg DQN Q value:  9.191
#  batch mean DQN best action probability:  34.317 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.084
# DQN WIS: 2.502
# train
# DQN WDR_: 9.257
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: -0.96
# DQN WIS: -1.93
# val
# DQN WDR_: 6.353
# DQN WIS_: -1.93
# ----------
# test
# DQN WDR: 2.887
# DQN WIS: 2.485
# test
# DQN WDR_: 8.185
# DQN WIS_: 2.485
# ----------
# ----------
# Saving interim Model 170000
# ----------
# ----------
# Epoch 171000/350000
#  batch loss:  0.04
#  running loss:  7.712
#  batch error:  5.082
#  batch avg Phy Q value:  7.792
#  batch avg DQN Q value:  9.289
#  batch mean DQN best action probability:  32.617 %
# ----------
# Epoch 172000/350000
#  batch loss:  0.055
#  running loss:  7.7
# ...
#  batch avg DQN Q value:  9.565
#  batch mean DQN best action probability:  35.111 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.043
# DQN WIS: 2.502
# train
# DQN WDR_: 8.399
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 1.078
# DQN WIS: 2.484
# val
# DQN WDR_: 8.556
# DQN WIS_: 2.484
# ----------
# test
# DQN WDR: 2.969
# DQN WIS: 2.4
# test
# DQN WDR_: 8.332
# DQN WIS_: 2.4
# ----------
# ----------
# Saving interim Model 295000
# ----------
# ----------
# Epoch 296000/350000
#  batch loss:  0.058
#  running loss:  6.67
#  batch error:  5.495
#  batch avg Phy Q value:  7.978
#  batch avg DQN Q value:  9.527
#  batch mean DQN best action probability:  31.021 %
# ----------
# Epoch 297000/350000
#  batch loss:  0.062
#  running loss:  6.665
#  batch error:  5.192
#  batch avg Phy Q value:  7.952
#  batch avg DQN Q value:  9.434
#  batch mean DQN best action probability:  32.128 %
# ----------
# Epoch 298000/350000
#  batch loss:  0.082
#  running loss:  6.659
#  batch error:  6.274
#  batch avg Phy Q value:  8.031
#  batch avg DQN Q value:  9.547
#  batch mean DQN best action probability:  32.637 %
# ----------
# Epoch 299000/350000
#  batch loss:  0.125
#  running loss:  6.653
#  batch error:  7.75
#  batch avg Phy Q value:  7.77
#  batch avg DQN Q value:  9.468
#  batch mean DQN best action probability:  33.224 %
# ----------
# Epoch 300000/350000
#  batch loss:  0.078
#  running loss:  6.647
#  batch error:  6.245
#  batch avg Phy Q value:  8.039
#  batch avg DQN Q value:  9.531
#  batch mean DQN best action probability:  32.752 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.048
# DQN WIS: 2.502
# train
# DQN WDR_: 8.975
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 1.209
# DQN WIS: 2.373
# val
# DQN WDR_: 8.517
# DQN WIS_: 2.373
# ----------
# test
# DQN WDR: 3.37
# DQN WIS: 2.48
# test
# DQN WDR_: 8.467
# DQN WIS_: 2.48
# ----------
# ----------
# Saving interim Model 300000
# ----------
# ----------
# Epoch 301000/350000
#  batch loss:  0.061
#  running loss:  6.642
#  batch error:  5.177
#  batch avg Phy Q value:  7.857
#  batch avg DQN Q value:  9.383
#  batch mean DQN best action probability:  32.224 %
# ----------
# Epoch 302000/350000
#  batch loss:  0.067
#  running loss:  6.636
#  batch error:  5.974
#  batch avg Phy Q value:  7.737
#  batch avg DQN Q value:  9.64
#  batch mean DQN best action probability:  35.781 %
# ----------
# Epoch 303000/350000
#  batch loss:  0.047
#  running loss:  6.631
#  batch error:  4.305
#  batch avg Phy Q value:  7.954
#  batch avg DQN Q value:  9.54
#  batch mean DQN best action probability:  35.559 %
# ----------
# Epoch 304000/350000
#  batch loss:  0.058
#  running loss:  6.625
#  batch error:  5.003
#  batch avg Phy Q value:  7.884
#  batch avg DQN Q value:  9.347
#  batch mean DQN best action probability:  33.45 %
# ----------
# Epoch 305000/350000
#  batch loss:  0.037
#  running loss:  6.619
#  batch error:  4.119
#  batch avg Phy Q value:  8.105
#  batch avg DQN Q value:  9.737
#  batch mean DQN best action probability:  35.88 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.26
# DQN WIS: 2.502
# train
# DQN WDR_: 8.193
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 0.961
# DQN WIS: 2.467
# val
# DQN WDR_: 8.202
# DQN WIS_: 2.467
# ----------
# test
# DQN WDR: 2.881
# DQN WIS: 2.467
# test
# DQN WDR_: 7.923
# DQN WIS_: 2.467
# ----------
# ----------
# Saving interim Model 305000
# ----------
# ----------
# Epoch 306000/350000
#  batch loss:  0.046
#  running loss:  6.614
#  batch error:  4.888
#  batch avg Phy Q value:  7.956
#  batch avg DQN Q value:  9.585
#  batch mean DQN best action probability:  32.344 %
# ----------
# Epoch 307000/350000
#  batch loss:  0.061
#  running loss:  6.608
#  batch error:  5.254
#  batch avg Phy Q value:  7.814
#  batch avg DQN Q value:  9.561
#  batch mean DQN best action probability:  33.388 %
# ----------
# Epoch 308000/350000
#  batch loss:  0.074
#  running loss:  6.602
#  batch error:  5.948
#  batch avg Phy Q value:  8.124
#  batch avg DQN Q value:  9.666
#  batch mean DQN best action probability:  34.025 %
# ----------
# Epoch 309000/350000
#  batch loss:  0.031
#  running loss:  6.596
#  batch error:  3.026
#  batch avg Phy Q value:  7.898
#  batch avg DQN Q value:  9.484
#  batch mean DQN best action probability:  34.412 %
# ----------
# Epoch 310000/350000
#  batch loss:  0.033
#  running loss:  6.591
#  batch error:  3.45
#  batch avg Phy Q value:  7.583
#  batch avg DQN Q value:  9.496
#  batch mean DQN best action probability:  32.092 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.275
# DQN WIS: 2.502
# train
# DQN WDR_: 8.47
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 1.28
# DQN WIS: 2.493
# val
# DQN WDR_: 8.624
# DQN WIS_: 2.493
# ----------
# test
# DQN WDR: 3.265
# DQN WIS: 2.486
# test
# DQN WDR_: 8.696
# DQN WIS_: 2.486
# ----------
# ----------
# Saving interim Model 310000
# ----------
# ----------
# Epoch 311000/350000
#  batch loss:  0.058
#  running loss:  6.585
#  batch error:  5.138
#  batch avg Phy Q value:  7.913
#  batch avg DQN Q value:  9.871
#  batch mean DQN best action probability:  36.107 %
# ----------
# Epoch 312000/350000
#  batch loss:  1.971
#  running loss:  6.579
#  batch error:  4.621
#  batch avg Phy Q value:  7.83
#  batch avg DQN Q value:  9.636
#  batch mean DQN best action probability:  32.234 %
# ----------
# Epoch 313000/350000
#  batch loss:  0.045
#  running loss:  6.574
#  batch error:  4.483
#  batch avg Phy Q value:  8.441
#  batch avg DQN Q value:  9.668
#  batch mean DQN best action probability:  34.156 %
# ----------
# Epoch 314000/350000
#  batch loss:  0.092
#  running loss:  6.568
#  batch error:  6.582
#  batch avg Phy Q value:  7.57
#  batch avg DQN Q value:  9.668
#  batch mean DQN best action probability:  32.621 %
# ----------
# Epoch 315000/350000
#  batch loss:  0.089
#  running loss:  6.562
#  batch error:  6.075
#  batch avg Phy Q value:  7.687
#  batch avg DQN Q value:  9.451
#  batch mean DQN best action probability:  33.662 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.319
# DQN WIS: 2.502
# train
# DQN WDR_: 8.421
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 0.744
# DQN WIS: 2.491
# val
# DQN WDR_: 7.477
# DQN WIS_: 2.491
# ----------
# test
# DQN WDR: 3.312
# DQN WIS: 2.479
# test
# DQN WDR_: 8.221
# DQN WIS_: 2.479
# ----------
# ----------
# Saving interim Model 315000
# ----------
# ----------
# Epoch 316000/350000
#  batch loss:  0.069
#  running loss:  6.557
#  batch error:  5.634
#  batch avg Phy Q value:  7.638
#  batch avg DQN Q value:  9.603
#  batch mean DQN best action probability:  32.742 %
# ----------
# Epoch 317000/350000
#  batch loss:  0.05
#  running loss:  6.552
#  batch error:  4.231
#  batch avg Phy Q value:  8.33
#  batch avg DQN Q value:  9.466
#  batch mean DQN best action probability:  32.462 %
# ----------
# Epoch 318000/350000
#  batch loss:  0.048
#  running loss:  6.546
#  batch error:  4.852
#  batch avg Phy Q value:  7.973
#  batch avg DQN Q value:  9.578
#  batch mean DQN best action probability:  34.099 %
# ----------
# Epoch 319000/350000
#  batch loss:  0.026
#  running loss:  6.541
#  batch error:  3.451
#  batch avg Phy Q value:  7.603
#  batch avg DQN Q value:  9.371
#  batch mean DQN best action probability:  31.802 %
# ----------
# Epoch 320000/350000
#  batch loss:  0.042
#  running loss:  6.536
#  batch error:  4.415
#  batch avg Phy Q value:  7.937
#  batch avg DQN Q value:  9.693
#  batch mean DQN best action probability:  35.716 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.276
# DQN WIS: 2.502
# train
# DQN WDR_: 7.646
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 0.739
# DQN WIS: 2.483
# val
# DQN WDR_: 7.144
# DQN WIS_: 2.483
# ----------
# test
# DQN WDR: 3.258
# DQN WIS: 2.485
# test
# DQN WDR_: 8.138
# DQN WIS_: 2.485
# ----------
# ----------
# Saving interim Model 320000
# ----------
# ----------
# Epoch 321000/350000
#  batch loss:  0.101
#  running loss:  6.53
#  batch error:  6.577
#  batch avg Phy Q value:  8.095
#  batch avg DQN Q value:  9.903
#  batch mean DQN best action probability:  36.265 %
# ----------
# Epoch 322000/350000
#  batch loss:  0.052
#  running loss:  6.525
#  batch error:  4.628
#  batch avg Phy Q value:  7.563
#  batch avg DQN Q value:  9.632
#  batch mean DQN best action probability:  34.381 %
# ----------
# Epoch 323000/350000
#  batch loss:  0.087
#  running loss:  6.52
#  batch error:  6.322
#  batch avg Phy Q value:  6.856
#  batch avg DQN Q value:  9.769
#  batch mean DQN best action probability:  35.944 %
# ----------
# Epoch 324000/350000
#  batch loss:  0.062
#  running loss:  6.514
#  batch error:  5.085
#  batch avg Phy Q value:  7.32
#  batch avg DQN Q value:  9.618
#  batch mean DQN best action probability:  35.208 %
# ----------
# Epoch 325000/350000
#  batch loss:  0.033
#  running loss:  6.509
#  batch error:  4.04
#  batch avg Phy Q value:  7.61
#  batch avg DQN Q value:  9.555
#  batch mean DQN best action probability:  32.355 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.316
# DQN WIS: 2.502
# train
# DQN WDR_: 7.28
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 1.15
# DQN WIS: 2.486
# val
# DQN WDR_: 8.38
# DQN WIS_: 2.486
# ----------
# test
# DQN WDR: 3.238
# DQN WIS: 2.473
# test
# DQN WDR_: 8.425
# DQN WIS_: 2.473
# ----------
# ----------
# Saving interim Model 325000
# ----------
# ----------
# Epoch 326000/350000
#  batch loss:  0.08
#  running loss:  6.503
#  batch error:  6.106
#  batch avg Phy Q value:  8.095
#  batch avg DQN Q value:  9.772
#  batch mean DQN best action probability:  34.851 %
# ----------
# Epoch 327000/350000
#  batch loss:  0.097
#  running loss:  6.498
#  batch error:  6.569
#  batch avg Phy Q value:  7.923
#  batch avg DQN Q value:  9.739
#  batch mean DQN best action probability:  33.178 %
# ----------
# Epoch 328000/350000
#  batch loss:  0.048
#  running loss:  6.493
#  batch error:  4.644
#  batch avg Phy Q value:  8.032
#  batch avg DQN Q value:  9.603
#  batch mean DQN best action probability:  35.036 %
# ----------
# Epoch 329000/350000
#  batch loss:  0.239
#  running loss:  6.487
#  batch error:  4.153
#  batch avg Phy Q value:  7.448
#  batch avg DQN Q value:  9.403
#  batch mean DQN best action probability:  31.356 %
# ----------
# Epoch 330000/350000
#  batch loss:  0.046
#  running loss:  6.482
#  batch error:  5.146
#  batch avg Phy Q value:  7.404
#  batch avg DQN Q value:  9.61
#  batch mean DQN best action probability:  33.748 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.262
# DQN WIS: 2.502
# train
# DQN WDR_: 8.034
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 1.012
# DQN WIS: 2.492
# val
# DQN WDR_: 8.384
# DQN WIS_: 2.492
# ----------
# test
# DQN WDR: 2.964
# DQN WIS: 2.497
# test
# DQN WDR_: 8.274
# DQN WIS_: 2.497
# ----------
# ----------
# Saving interim Model 330000
# ----------
# ----------
# Epoch 331000/350000
#  batch loss:  0.049
#  running loss:  6.477
#  batch error:  4.474
#  batch avg Phy Q value:  7.803
#  batch avg DQN Q value:  9.79
#  batch mean DQN best action probability:  36.383 %
# ----------
# Epoch 332000/350000
#  batch loss:  0.056
#  running loss:  6.472
#  batch error:  4.98
#  batch avg Phy Q value:  8.214
#  batch avg DQN Q value:  9.649
#  batch mean DQN best action probability:  32.986 %
# ----------
# Epoch 333000/350000
#  batch loss:  0.074
#  running loss:  6.467
#  batch error:  5.671
#  batch avg Phy Q value:  7.545
#  batch avg DQN Q value:  9.52
#  batch mean DQN best action probability:  34.04 %
# ----------
# Epoch 334000/350000
#  batch loss:  0.056
#  running loss:  6.462
#  batch error:  5.049
#  batch avg Phy Q value:  8.157
#  batch avg DQN Q value:  9.817
#  batch mean DQN best action probability:  36.836 %
# ----------
# Epoch 335000/350000
#  batch loss:  0.032
#  running loss:  6.457
#  batch error:  3.772
#  batch avg Phy Q value:  7.75
#  batch avg DQN Q value:  9.565
#  batch mean DQN best action probability:  32.708 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.276
# DQN WIS: 2.502
# train
# DQN WDR_: 8.653
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 0.563
# DQN WIS: 2.485
# val
# DQN WDR_: 8.455
# DQN WIS_: 2.485
# ----------
# test
# DQN WDR: 3.212
# DQN WIS: 2.47
# test
# DQN WDR_: 8.551
# DQN WIS_: 2.47
# ----------
# ----------
# Saving interim Model 335000
# ----------
# ----------
# Epoch 336000/350000
#  batch loss:  0.082
#  running loss:  6.452
#  batch error:  5.452
#  batch avg Phy Q value:  7.894
#  batch avg DQN Q value:  9.556
#  batch mean DQN best action probability:  34.807 %
# ----------
# Epoch 337000/350000
#  batch loss:  0.025
#  running loss:  6.446
#  batch error:  3.239
#  batch avg Phy Q value:  7.796
#  batch avg DQN Q value:  9.507
#  batch mean DQN best action probability:  31.749 %
# ----------
# Epoch 338000/350000
#  batch loss:  0.048
#  running loss:  6.441
#  batch error:  5.206
#  batch avg Phy Q value:  7.391
#  batch avg DQN Q value:  10.029
#  batch mean DQN best action probability:  38.421 %
# ----------
# Epoch 339000/350000
#  batch loss:  0.028
#  running loss:  6.436
#  batch error:  4.009
#  batch avg Phy Q value:  8.003
#  batch avg DQN Q value:  9.563
#  batch mean DQN best action probability:  32.994 %
# ----------
# Epoch 340000/350000
#  batch loss:  0.045
#  running loss:  6.431
#  batch error:  4.438
#  batch avg Phy Q value:  7.866
#  batch avg DQN Q value:  9.881
#  batch mean DQN best action probability:  39.652 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.49
# DQN WIS: 2.502
# train
# DQN WDR_: 9.113
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 0.863
# DQN WIS: 2.49
# val
# DQN WDR_: 10.603
# DQN WIS_: 2.49
# ----------
# test
# DQN WDR: 3.123
# DQN WIS: 2.482
# test
# DQN WDR_: 9.128
# DQN WIS_: 2.482
# ----------
# ----------
# Saving interim Model 340000
# ----------
# ----------
# Epoch 341000/350000
#  batch loss:  0.056
#  running loss:  6.426
#  batch error:  4.875
#  batch avg Phy Q value:  7.442
#  batch avg DQN Q value:  9.695
#  batch mean DQN best action probability:  36.325 %
# ----------
# Epoch 342000/350000
#  batch loss:  0.026
#  running loss:  6.422
#  batch error:  3.149
#  batch avg Phy Q value:  8.026
#  batch avg DQN Q value:  9.607
#  batch mean DQN best action probability:  33.523 %
# ----------
# Epoch 343000/350000
#  batch loss:  0.042
#  running loss:  6.417
#  batch error:  4.151
#  batch avg Phy Q value:  8.049
#  batch avg DQN Q value:  9.685
#  batch mean DQN best action probability:  33.303 %
# ----------
# Epoch 344000/350000
#  batch loss:  0.054
#  running loss:  6.412
#  batch error:  4.511
#  batch avg Phy Q value:  7.886
#  batch avg DQN Q value:  9.557
#  batch mean DQN best action probability:  33.721 %
# ----------
# Epoch 345000/350000
#  batch loss:  0.04
#  running loss:  6.407
#  batch error:  4.392
#  batch avg Phy Q value:  7.999
#  batch avg DQN Q value:  9.695
#  batch mean DQN best action probability:  36.03 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.018
# DQN WIS: 2.502
# train
# DQN WDR_: 8.886
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 0.185
# DQN WIS: 2.434
# val
# DQN WDR_: 10.651
# DQN WIS_: 2.434
# ----------
# test
# DQN WDR: 2.808
# DQN WIS: 2.414
# test
# DQN WDR_: 8.784
# DQN WIS_: 2.414
# ----------
# ----------
# Saving interim Model 345000
# ----------
# ----------
# Epoch 346000/350000
#  batch loss:  0.029
#  running loss:  6.402
#  batch error:  3.878
#  batch avg Phy Q value:  7.985
#  batch avg DQN Q value:  9.878
#  batch mean DQN best action probability:  35.509 %
# ----------
# Epoch 347000/350000
#  batch loss:  0.092
#  running loss:  6.397
#  batch error:  6.778
#  batch avg Phy Q value:  7.802
#  batch avg DQN Q value:  9.767
#  batch mean DQN best action probability:  38.027 %
# ----------
# Epoch 348000/350000
#  batch loss:  0.073
#  running loss:  6.392
#  batch error:  5.781
#  batch avg Phy Q value:  8.06
#  batch avg DQN Q value:  9.687
#  batch mean DQN best action probability:  34.341 %
# ----------
# Epoch 349000/350000
#  batch loss:  0.045
#  running loss:  6.388
#  batch error:  4.268
#  batch avg Phy Q value:  8.255
#  batch avg DQN Q value:  9.703
#  batch mean DQN best action probability:  33.459 %
# ----------
# Epoch 350000/350000
#  batch loss:  0.046
#  running loss:  6.383
#  batch error:  4.597
#  batch avg Phy Q value:  7.938
#  batch avg DQN Q value:  9.765
#  batch mean DQN best action probability:  35.994 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 0.071
# DQN WIS: 2.502
# train
# DQN WDR_: 8.551
# DQN WIS_: 2.502
# ----------
# val
# DQN WDR: 0.755
# DQN WIS: 2.488
# val
# DQN WDR_: 9.805
# DQN WIS_: 2.488
# ----------
# test
# DQN WDR: 2.927
# DQN WIS: 2.471
# test
# DQN WDR_: 9.582
# DQN WIS_: 2.471
# ----------
# ----------
# Saving interim Model 350000
# ----------
#
# Training complete in 128m 13s
#
# -----------------
# FINISHED TRAINING ALL EXPERIMENTS
# -----------------
# lucspace
# Finished at: 2022-06-10 12:51:01.246374
# Experiment complete in 2 hours, 8 minutes and 31 seconds
