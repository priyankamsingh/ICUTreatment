# %% [markdown]
# #### Run the DQN model on Extended space data

# %%
import os
import sys
import joblib 
from datetime import datetime 
import time
from multiprocessing import cpu_count 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce
from sklearn.model_selection import ParameterGrid
import torch 
from torch import optim , nn 
from utils import train_model_double, dueling_net
use_gpu = torch.cuda.is_available()

# %%
### Experiment name 
exp_name = 'ess_b32_h128_lr1e4_g99' # but i am running 1e-5

### OPTIONAL: Continue training
continue_training = False
cont_exp_grid_run = 0
original_exp_name = exp_name

#### super OPTIONAL: Continue training a previous interim model
continue_interim = False
continue_interim_i = 0

# %%
# import your RL data dict from this directory 
data_dir = '../data/'
dict_file = 'ess_data_dict.pkl'

# Give path to model dir 
model_dir = '../models/'
interimdir = '../interimfiles/'
performance_dir = '../performance/'

## experiment dir 
exp_dir = '../'

# %% [markdown]
# #### Read required file for model building

# %%
## Reading RL data 
data_dict = joblib.load(os.path.join(data_dir, 'ess_data_dict.pkl'))

# Action probabilities of physician's action used for intermediate evaluateion
train_pi_behavior = pd.read_pickle(os.path.join(data_dir, 'KNN_pi_behavior_' + 'train' + 'data.pkl')) # pi_evaluation
val_pi_behavior = pd.read_pickle(os.path.join(data_dir, 'KNN_pi_behavior_' + 'val' + 'data.pkl')) # pi_evaluation
test_pi_behavior = pd.read_pickle(os.path.join(data_dir, 'KNN_pi_behavior_' + 'test' + 'data.pkl')) # pi_evaluation

# dataset MDP Q function (FQI-SARSA)
train_MDP_Q = pd.read_pickle(os.path.join(data_dir, 'FQI_QValues_' + 'train' + 'data.pkl'))
val_MDP_Q = pd.read_pickle(os.path.join(data_dir, 'FQI_QValues_' + 'val' + 'data.pkl'))
test_MDP_Q = pd.read_pickle(os.path.join(data_dir, 'FQI_QValues_' + 'test' + 'data.pkl'))

#create MDP dictionary to pass to teh model 
data_dict_MDP = {'train_pi_behavior': train_pi_behavior,
                 'val_pi_behavior': val_pi_behavior,
                 'test_pi_behavior': test_pi_behavior,
                 'train_MDP_Q': train_MDP_Q,
                 'val_MDP_Q': val_MDP_Q,
                 'test_MDP_Q': test_MDP_Q
                }

# %%
###################
# define hyperparameter tuning grid
param_options = {   'state_dim' :         [data_dict['train']['X'].shape[1]],  
                    'action_dim' :        [21],                                 
                    'gamma' :             [0.99],                              
                    'batch_size' :        [32],#, 64],#,128],                        
                    'lr' :                [1e-4],  #1e-4]                             
                    'num_epochs' :        [300000],                             
                    'hidden_dim' :        [128],# 256],                           
                    'num_hidden' :        [2],                       
                    'drop_prob' :         [0.0],                         
                    'option' :            ['linear'],                  
                    'use_scheduler':      ['ReduceLROnPlateau'],                       
                    'scheduler_gamma':    [0.9],#,0.99],                       
                    'sched_step_size':    [30000],#,50000],                  
                    'tau':                [1e-3],                       
                    'reg_lambda' :        [5],                            
                    'REWARD_THRESHOLD' :  [15],                               
                    'PER_beta_start' :    [0.9],                             
                    'PER_alpha' :         [0.6],                        
                    'PER_epsilon' :       [0.01],                      
                    'PER_sample_alpha' :  [0.0],                            
                    'PER_start_prob' :    [0.001],                          
                    'use_GPU':            [use_gpu],                            
                    'tracking_step_eval':           [10000],                     
                    'tracking_step_interim_model':  [10000],                     
                    'tracking_console_print':       [1000]                      
         }

## Create parameter grid 
config_grid = ParameterGrid(param_options)

# %%
print('\n-----------------\nSTART EXPERIMENT')
print("experiment: " + exp_name)
print("Started at: " + str(datetime.now()) + "\n-----------------")
total_since = time.time()
exp_grid_run = 0
# For each configuration LOOP
for config in config_grid:
    exp_grid_run +=1
    if not os.path.exists(os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) )):
        os.makedirs(os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) ))

    ###################
    ### Models
    model = dueling_net(D_in=config['state_dim'],
                        H=config['hidden_dim'],
                        D_out=config['action_dim'],
                        drop_prob=config['drop_prob'],
                        num_hidden=config['num_hidden'],
                        option=config['option']
                        )

    target_model = dueling_net(D_in=config['state_dim'],
                               H=config['hidden_dim'],
                               D_out=config['action_dim'],
                               drop_prob=config['drop_prob'],
                               num_hidden=config['num_hidden'],
                               option=config['option']
                               )
        
    ###################
    ### Optimizer
    optimizer = optim.Adam([{'params': model.parameters()}],
                           lr=config['lr'])

    ###################
    ### Scheduler
    if config['use_scheduler'] == 'ReduceLROnPlateau':
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', verbose=True)
    elif config['use_scheduler'] == 'StepLR':      
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=config['scheduler_gamma']) # step size applied with config['sched_step_size'] in util.py train function
    else:
        scheduler = None

    def weights_init(m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight.data).float()   
            
    ###################
    ### Create CONFIG dataframe for saving to disk
    config_df = pd.DataFrame(config, index=[0])
            
    ###################
    # OPTIONAL: Load previous model    
    if continue_training: 
        
        ###################
        # This is a mess
        exp_name = original_exp_name + '_' + str(cont_exp_grid_run) + '_continued'
        new_exp_dir = os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) )
        
        # create model_continued model directory
        if not os.path.exists(new_exp_dir):
            os.makedirs(new_exp_dir)
        
        # load moel
        if continue_interim: 
            exp_model = original_exp_name + '/models/' + original_exp_name + '_' + str(cont_exp_grid_run) + '/' + original_exp_name + '_' + str(cont_exp_grid_run) + '_interim_' + str(continue_interim_i) + '_iteration_model.chk'
        else:
            exp_model = original_exp_name + '/models/' + original_exp_name + '_' + str(cont_exp_grid_run) + '_model.chk'
            
        #selected_model = os.path.join(conf.EXP_DIR, exp_model) 
        selected_model = os.path.join(exp_model)

        ###################    
        # CPU or GPU, let the budget decide!  
        if use_gpu:
            model = model.cuda()
            target_model = target_model.cuda()
            model.load_state_dict(torch.load(selected_model))
            target_model.load_state_dict(torch.load(selected_model))
        else:
            model.load_state_dict(torch.load(selected_model, map_location=lambda storage, loc: storage))
            target_model.load_state_dict(torch.load(selected_model, map_location=lambda storage, loc: storage))
        
        ###################
        # experiment name and location for interim model saving
        experiment = { 'exp_name': exp_name, 'exp_dir': exp_dir, 'exp_grid_run': exp_grid_run, 'exp_grid_total_runs': len(config_grid) }
            
        # Save CONFIG dataframe to disk and set location for FINAL model saving 
        checkpoints_path = os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) + '_model.chk')
        config_df.to_csv(os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) + '_config.csv'), index=False)
        
    ###################
    # IF NOT LOADING PREVIOUS MODEL, START FRESH
    else:
        ###################
        # initialize model weights
        model.apply(weights_init)
        target_model.apply(weights_init)
        if use_gpu:
            model = model.cuda()
            target_model = target_model.cuda()
            
        # experiment name and location for interim model saving
        experiment = { 'exp_name': exp_name, 'exp_dir': exp_dir, 'exp_grid_run': exp_grid_run, 'exp_grid_total_runs': len(config_grid) }
    
        ###################
        # Save CONFIG dataframe to disk and set location for FINAL model saving
        checkpoints_path = os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) + '_model.chk')
        config_df.to_csv(os.path.join(exp_dir, 'models/' + exp_name + "_" + str(exp_grid_run) + '_config.csv'), index=False)

        
    ############################################################################  
    if continue_training:
        print('\n-----------------\nSTART CONTINUED MODEL TRAINING')
    else:        
        print('\n-----------------\nSTART MODEL TRAINING')
    print("Experiment name: " + exp_name)
    print("Experiment " + str(exp_grid_run) + ' out of ' + str(len(config_grid)))
    print("configuration of model: ")
    print('-----------------')
   
    ###################
    # This is probably what your looking for, the actual model training... it's at the end of util.py, you're welcome!
    tracking_performance_dict, performance_dict, best_model = train_model_double(model=model,
                                                                                 target_model=target_model,
                                                                                 data_dict=data_dict,
                                                                                 data_dict_MDP=data_dict_MDP,
                                                                                 config=config,
                                                                                 optimizer=optimizer,
                                                                                 scheduler=scheduler,
                                                                                 experiment=experiment,
                                                                                 use_gpu=use_gpu)

    ###################
    # save best model of this config run
    torch.save(best_model.state_dict(), checkpoints_path)
    
    # create dictionaries
    performance_df = pd.DataFrame.from_dict(performance_dict)
    tracking_performance_df = pd.DataFrame.from_dict(tracking_performance_dict)

    # write to csv
    tracking_performance_df.to_csv(os.path.join(exp_dir, 'performance/' + exp_name + "_" + str(exp_grid_run) + '_tracking_performance.csv'), index=False)
    performance_df.to_csv(os.path.join(exp_dir, 'performance/' + exp_name + "_" + str(exp_grid_run) + '_performance.csv'), index=False)
    
################################################################################################################
################################################################################################################
time_elapsed = time.time() - total_since
hours = time_elapsed//3600
temp = time_elapsed - 3600*hours
minutes = temp//60
seconds = temp - 60*minutes
print('\n-----------------\nFINISHED TRAINING ALL EXPERIMENTS\n-----------------')
print(exp_name)
print("Finished at: " + str(datetime.now()))
print('Experiment complete in %d hours, %d minutes and %d seconds' %(hours,minutes,seconds))
# Out:
# -----------------
# START EXPERIMENT
# experiment: ess_b32_h128_lr1e4_g99
# Started at: 2022-06-20 01:20:41.431838
# -----------------
#
# -----------------
# START MODEL TRAINING
# Experiment name: ess_b32_h128_lr1e4_g99
# Experiment 1 out of 1
# configuration of model:
# -----------------
# ----------
# Epoch 1000/300000
#  batch loss:  0.18
#  running loss:  13.613
#  batch error:  12.834
#  batch avg Phy Q value:  1.75
#  batch avg DQN Q value:  3.122
#  batch mean DQN best action probability:  30.002 %
# ----------
# Epoch 2000/300000
#  batch loss:  0.184
#  running loss:  13.191
#  batch error:  12.49
#  batch avg Phy Q value:  2.455
#  batch avg DQN Q value:  3.685
#  batch mean DQN best action probability:  33.648 %
# ----------
# Epoch 3000/300000
#  batch loss:  0.294
#  running loss:  12.88
#  batch error:  11.937
#  batch avg Phy Q value:  3.39
#  batch avg DQN Q value:  4.67
#  batch mean DQN best action probability:  42.036 %
# ----------
# Epoch 4000/300000
#  batch loss:  0.145
#  running loss:  12.599
#  batch error:  11.73
#  batch avg Phy Q value:  3.663
#  batch avg DQN Q value:  4.968
#  batch mean DQN best action probability:  42.307 %
# ----------
# Epoch 5000/300000
#  batch loss:  0.132
#  running loss:  12.37
#  batch error:  11.095
#  batch avg Phy Q value:  4.206
#  batch avg DQN Q value:  5.474
#  batch mean DQN best action probability:  43.178 %
# ----------
# Epoch 6000/300000
#  batch loss:  0.129
#  running loss:  12.162
#  batch error:  10.8
#  batch avg Phy Q value:  4.092
#  batch avg DQN Q value:  5.418
#  batch mean DQN best action probability:  32.728 %
# ----------
# Epoch 7000/300000
#  batch loss:  0.198
#  running loss:  11.968
#  batch error:  9.761
#  batch avg Phy Q value:  4.791
#  batch avg DQN Q value:  5.944
#  batch mean DQN best action probability:  39.09 %
# ----------
# Epoch 8000/300000
#  batch loss:  0.181
#  running loss:  11.785
#  batch error:  11.626
#  batch avg Phy Q value:  4.307
#  batch avg DQN Q value:  5.557
#  batch mean DQN best action probability:  30.897 %
# ----------
# Epoch 9000/300000
#  batch loss:  0.129
#  running loss:  11.634
#  batch error:  10.716
#  batch avg Phy Q value:  5.103
#  batch avg DQN Q value:  6.23
#  batch mean DQN best action probability:  40.311 %
# ----------
# Epoch 10000/300000
#  batch loss:  0.128
#  running loss:  11.507
#  batch error:  10.402
#  batch avg Phy Q value:  4.95
#  batch avg DQN Q value:  6.127
#  batch mean DQN best action probability:  35.878 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: -3.032
# DQN WIS: -7.639
# ----------
# val
# DQN WDR: 3.794
# DQN WIS: 5.237
# ----------
# test
# DQN WDR: 3.797
# DQN WIS: 3.35
# ----------
# ----------
# Saving interim Model 10000
# ----------
# Epoch 11000/300000
#  batch loss:  0.148
#  running loss:  11.399
#  batch error:  11.428
#  batch avg Phy Q value:  5.076
#  batch avg DQN Q value:  6.342
#  batch mean DQN best action probability:  39.124 %
# ----------
# Epoch 12000/300000
#  batch loss:  0.151
#  running loss:  11.296
#  batch error:  10.669
#  batch avg Phy Q value:  5.447
#  batch avg DQN Q value:  6.374
#  batch mean DQN best action probability:  35.38 %
# ----------
# Epoch 13000/300000
#  batch loss:  0.171
#  running loss:  11.187
#  batch error:  11.725
#  batch avg Phy Q value:  5.431
#  batch avg DQN Q value:  6.463
#  batch mean DQN best action probability:  33.992 %
# ----------
# Epoch 14000/300000
#  batch loss:  0.106
#  running loss:  11.088
#  batch error:  9.508
#  batch avg Phy Q value:  5.979
#  batch avg DQN Q value:  6.853
#  batch mean DQN best action probability:  35.442 %
# ----------
# Epoch 15000/300000
#  batch loss:  0.09
#  running loss:  10.997
#  batch error:  8.695
#  batch avg Phy Q value:  6.021
#  batch avg DQN Q value:  6.974
#  batch mean DQN best action probability:  38.014 %
# ----------
# Epoch 16000/300000
#  batch loss:  0.124
#  running loss:  10.923
#  batch error:  9.685
#  batch avg Phy Q value:  6.037
#  batch avg DQN Q value:  6.88
#  batch mean DQN best action probability:  37.103 %
# ----------
# Epoch 17000/300000
#  batch loss:  0.109
#  running loss:  10.854
#  batch error:  9.542
#  batch avg Phy Q value:  6.358
#  batch avg DQN Q value:  7.102
#  batch mean DQN best action probability:  36.206 %
# ----------
# Epoch 18000/300000
#  batch loss:  0.095
#  running loss:  10.782
#  batch error:  8.311
#  batch avg Phy Q value:  5.697
#  batch avg DQN Q value:  6.995
#  batch mean DQN best action probability:  32.177 %
# ----------
# Epoch 19000/300000
#  batch loss:  0.12
#  running loss:  10.704
#  batch error:  9.419
#  batch avg Phy Q value:  6.22
#  batch avg DQN Q value:  7.237
#  batch mean DQN best action probability:  33.698 %
# ----------
# Epoch 20000/300000
#  batch loss:  0.138
#  running loss:  10.631
#  batch error:  10.379
#  batch avg Phy Q value:  5.843
#  batch avg DQN Q value:  7.087
#  batch mean DQN best action probability:  34.786 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 4.483
# DQN WIS: 9.325
# ----------
# val
# DQN WDR: 13.802
# DQN WIS: 12.638
# ----------
# test
# DQN WDR: -8.878
# DQN WIS: -12.081
# ----------
# ----------
# Saving interim Model 20000
# ----------
# Epoch 21000/300000
#  batch loss:  0.129
#  running loss:  10.572
#  batch error:  9.027
#  batch avg Phy Q value:  6.12
#  batch avg DQN Q value:  7.166
#  batch mean DQN best action probability:  36.498 %
# ----------
# Epoch 22000/300000
#  batch loss:  0.143
#  running loss:  10.513
#  batch error:  9.784
#  batch avg Phy Q value:  6.661
#  batch avg DQN Q value:  7.344
#  batch mean DQN best action probability:  36.174 %
# ----------
# Epoch 23000/300000
#  batch loss:  0.092
#  running loss:  10.452
#  batch error:  8.293
#  batch avg Phy Q value:  6.556
#  batch avg DQN Q value:  7.727
#  batch mean DQN best action probability:  40.022 %
# ----------
# Epoch 24000/300000
#  batch loss:  0.118
#  running loss:  10.391
#  batch error:  9.109
#  batch avg Phy Q value:  6.457
#  batch avg DQN Q value:  7.424
#  batch mean DQN best action probability:  33.418 %
# ----------
# Epoch 25000/300000
#  batch loss:  0.123
#  running loss:  10.335
#  batch error:  8.971
#  batch avg Phy Q value:  6.676
#  batch avg DQN Q value:  7.265
#  batch mean DQN best action probability:  31.341 %
# ----------
# Epoch 26000/300000
#  batch loss:  0.109
#  running loss:  10.283
#  batch error:  9.043
#  batch avg Phy Q value:  6.253
#  batch avg DQN Q value:  7.203
#  batch mean DQN best action probability:  28.589 %
# ----------
# Epoch 27000/300000
#  batch loss:  0.127
#  running loss:  10.234
#  batch error:  9.632
#  batch avg Phy Q value:  5.881
#  batch avg DQN Q value:  7.245
#  batch mean DQN best action probability:  30.255 %
# ----------
# Epoch 28000/300000
#  batch loss:  0.107
#  running loss:  10.18
#  batch error:  9.071
#  batch avg Phy Q value:  6.607
#  batch avg DQN Q value:  7.629
#  batch mean DQN best action probability:  31.536 %
# ----------
# Epoch 29000/300000
#  batch loss:  0.101
#  running loss:  10.128
#  batch error:  8.368
#  batch avg Phy Q value:  6.493
#  batch avg DQN Q value:  7.707
#  batch mean DQN best action probability:  35.618 %
# ----------
# Epoch 30000/300000
#  batch loss:  0.121
#  running loss:  10.084
#  batch error:  9.644
#  batch avg Phy Q value:  6.621
#  batch avg DQN Q value:  7.601
#  batch mean DQN best action probability:  34.568 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.24
# DQN WIS: 12.635
# ----------
# val
# DQN WDR: 12.639
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: 8.715
# DQN WIS: 6.304
# ----------
# ----------
# Saving interim Model 30000
# ----------
# Epoch 31000/300000
#  batch loss:  0.074
#  running loss:  10.041
#  batch error:  7.171
#  batch avg Phy Q value:  7.175
#  batch avg DQN Q value:  8.004
#  batch mean DQN best action probability:  36.624 %
# ----------
# Epoch 32000/300000
#  batch loss:  0.16
#  running loss:  9.992
#  batch error:  8.604
#  batch avg Phy Q value:  6.966
#  batch avg DQN Q value:  8.118
#  batch mean DQN best action probability:  36.815 %
# ----------
# Epoch 33000/300000
#  batch loss:  0.127
#  running loss:  9.945
#  batch error:  9.359
#  batch avg Phy Q value:  7.176
#  batch avg DQN Q value:  8.002
#  batch mean DQN best action probability:  34.821 %
# ----------
# Epoch 34000/300000
#  batch loss:  0.112
#  running loss:  9.901
#  batch error:  8.445
#  batch avg Phy Q value:  7.398
#  batch avg DQN Q value:  8.163
#  batch mean DQN best action probability:  35.017 %
# ----------
# Epoch 35000/300000
#  batch loss:  0.079
#  running loss:  9.853
#  batch error:  7.024
#  batch avg Phy Q value:  7.309
#  batch avg DQN Q value:  8.339
#  batch mean DQN best action probability:  34.798 %
# ----------
# Epoch 36000/300000
#  batch loss:  0.135
#  running loss:  9.807
#  batch error:  9.403
#  batch avg Phy Q value:  7.022
#  batch avg DQN Q value:  8.533
#  batch mean DQN best action probability:  35.791 %
# ----------
# Epoch 37000/300000
#  batch loss:  0.095
#  running loss:  9.762
#  batch error:  7.868
#  batch avg Phy Q value:  7.352
#  batch avg DQN Q value:  8.252
#  batch mean DQN best action probability:  30.813 %
# ----------
# Epoch 38000/300000
#  batch loss:  0.074
#  running loss:  9.719
#  batch error:  6.883
#  batch avg Phy Q value:  7.571
#  batch avg DQN Q value:  8.258
#  batch mean DQN best action probability:  30.069 %
# ----------
# Epoch 39000/300000
#  batch loss:  0.069
#  running loss:  9.678
#  batch error:  6.641
#  batch avg Phy Q value:  7.731
#  batch avg DQN Q value:  8.649
#  batch mean DQN best action probability:  37.088 %
# ----------
# Epoch 40000/300000
#  batch loss:  0.1
#  running loss:  9.638
#  batch error:  7.449
#  batch avg Phy Q value:  7.341
#  batch avg DQN Q value:  8.438
#  batch mean DQN best action probability:  32.03 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.189
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 12.794
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: -7.329
# DQN WIS: -12.288
# ----------
# ----------
# Saving interim Model 40000
# ----------
# Epoch 41000/300000
#  batch loss:  0.167
#  running loss:  9.602
#  batch error:  10.23
#  batch avg Phy Q value:  7.397
#  batch avg DQN Q value:  8.65
#  batch mean DQN best action probability:  34.025 %
# ----------
# Epoch 42000/300000
#  batch loss:  0.151
#  running loss:  9.564
#  batch error:  9.944
#  batch avg Phy Q value:  7.097
#  batch avg DQN Q value:  8.372
#  batch mean DQN best action probability:  29.277 %
# ----------
# Epoch 43000/300000
#  batch loss:  0.104
#  running loss:  9.527
#  batch error:  7.947
#  batch avg Phy Q value:  7.517
#  batch avg DQN Q value:  8.579
#  batch mean DQN best action probability:  31.183 %
# ----------
# Epoch 44000/300000
#  batch loss:  0.133
#  running loss:  9.488
#  batch error:  9.299
#  batch avg Phy Q value:  6.981
#  batch avg DQN Q value:  8.672
#  batch mean DQN best action probability:  36.043 %
# ----------
# Epoch 45000/300000
#  batch loss:  0.117
#  running loss:  9.455
#  batch error:  8.811
#  batch avg Phy Q value:  7.403
#  batch avg DQN Q value:  8.539
#  batch mean DQN best action probability:  35.103 %
# ----------
# Epoch 46000/300000
#  batch loss:  0.131
#  running loss:  9.418
#  batch error:  8.824
#  batch avg Phy Q value:  7.635
#  batch avg DQN Q value:  8.621
#  batch mean DQN best action probability:  32.819 %
# ----------
# Epoch 47000/300000
#  batch loss:  0.124
#  running loss:  9.382
#  batch error:  8.777
#  batch avg Phy Q value:  7.681
#  batch avg DQN Q value:  8.684
#  batch mean DQN best action probability:  32.469 %
# ----------
# Epoch 48000/300000
#  batch loss:  0.154
#  running loss:  9.348
#  batch error:  8.084
#  batch avg Phy Q value:  7.602
#  batch avg DQN Q value:  8.553
#  batch mean DQN best action probability:  31.316 %
# ----------
# Epoch 49000/300000
#  batch loss:  0.072
#  running loss:  9.314
#  batch error:  6.628
#  batch avg Phy Q value:  7.771
#  batch avg DQN Q value:  8.43
#  batch mean DQN best action probability:  32.179 %
# ----------
# Epoch 50000/300000
#  batch loss:  0.054
#  running loss:  9.282
#  batch error:  5.565
#  batch avg Phy Q value:  7.63
#  batch avg DQN Q value:  8.542
#  batch mean DQN best action probability:  32.481 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.038
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.197
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: 1.96
# DQN WIS: -1.16
# ----------
# ----------
# Saving interim Model 50000
# ----------
# Epoch 51000/300000
#  batch loss:  0.07
#  running loss:  9.249
#  batch error:  6.616
#  batch avg Phy Q value:  7.601
#  batch avg DQN Q value:  8.758
#  batch mean DQN best action probability:  34.763 %
# ----------
# Epoch 52000/300000
#  batch loss:  0.058
#  running loss:  9.218
#  batch error:  5.305
#  batch avg Phy Q value:  7.491
#  batch avg DQN Q value:  8.809
#  batch mean DQN best action probability:  34.665 %
# ----------
# Epoch 53000/300000
#  batch loss:  0.068
#  running loss:  9.185
#  batch error:  6.062
#  batch avg Phy Q value:  7.535
#  batch avg DQN Q value:  8.798
#  batch mean DQN best action probability:  31.919 %
# ----------
# Epoch 54000/300000
#  batch loss:  0.363
#  running loss:  9.151
#  batch error:  8.522
#  batch avg Phy Q value:  7.504
#  batch avg DQN Q value:  8.61
#  batch mean DQN best action probability:  29.31 %
# ----------
# Epoch 55000/300000
#  batch loss:  0.106
#  running loss:  9.119
#  batch error:  7.366
#  batch avg Phy Q value:  7.84
#  batch avg DQN Q value:  8.759
#  batch mean DQN best action probability:  29.877 %
# ----------
# Epoch 56000/300000
#  batch loss:  0.092
#  running loss:  9.088
#  batch error:  7.228
#  batch avg Phy Q value:  8.165
#  batch avg DQN Q value:  9.24
#  batch mean DQN best action probability:  34.759 %
# ----------
# Epoch 57000/300000
#  batch loss:  0.091
#  running loss:  9.058
#  batch error:  6.935
#  batch avg Phy Q value:  7.409
#  batch avg DQN Q value:  8.943
#  batch mean DQN best action probability:  33.513 %
# ----------
# Epoch 58000/300000
#  batch loss:  0.085
#  running loss:  9.031
#  batch error:  7.534
#  batch avg Phy Q value:  7.84
#  batch avg DQN Q value:  9.068
#  batch mean DQN best action probability:  34.315 %
# ----------
# Epoch 59000/300000
#  batch loss:  0.046
#  running loss:  9.004
#  batch error:  5.492
#  batch avg Phy Q value:  7.658
#  batch avg DQN Q value:  9.011
#  batch mean DQN best action probability:  31.02 %
# ----------
# Epoch 60000/300000
#  batch loss:  0.081
#  running loss:  8.976
#  batch error:  6.3
#  batch avg Phy Q value:  7.754
#  batch avg DQN Q value:  8.98
#  batch mean DQN best action probability:  31.76 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 12.569
# DQN WIS: 12.641
# ----------
# val
# DQN WDR: 13.691
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: -4.448
# DQN WIS: -7.081
# ----------
# ----------
# Saving interim Model 60000
# ----------
# Epoch 61000/300000
#  batch loss:  0.105
#  running loss:  8.95
#  batch error:  7.496
#  batch avg Phy Q value:  7.657
#  batch avg DQN Q value:  9.133
#  batch mean DQN best action probability:  34.512 %
# ----------
# Epoch 62000/300000
#  batch loss:  0.115
#  running loss:  8.923
#  batch error:  8.36
#  batch avg Phy Q value:  7.431
#  batch avg DQN Q value:  9.066
#  batch mean DQN best action probability:  33.241 %
# ----------
# Epoch 63000/300000
#  batch loss:  0.085
#  running loss:  8.899
#  batch error:  7.142
#  batch avg Phy Q value:  7.873
#  batch avg DQN Q value:  9.159
#  batch mean DQN best action probability:  33.275 %
# ----------
# Epoch 64000/300000
#  batch loss:  0.082
#  running loss:  8.874
#  batch error:  7.154
#  batch avg Phy Q value:  7.823
#  batch avg DQN Q value:  8.849
#  batch mean DQN best action probability:  29.242 %
# ----------
# Epoch 65000/300000
#  batch loss:  0.087
#  running loss:  8.848
#  batch error:  7.305
#  batch avg Phy Q value:  7.97
#  batch avg DQN Q value:  9.358
#  batch mean DQN best action probability:  33.382 %
# ----------
# Epoch 66000/300000
#  batch loss:  0.1
#  running loss:  8.821
#  batch error:  7.17
#  batch avg Phy Q value:  7.694
#  batch avg DQN Q value:  9.124
#  batch mean DQN best action probability:  32.092 %
# ----------
# Epoch 67000/300000
#  batch loss:  0.047
#  running loss:  8.798
#  batch error:  5.346
#  batch avg Phy Q value:  7.589
#  batch avg DQN Q value:  9.096
#  batch mean DQN best action probability:  30.004 %
# ----------
# Epoch 68000/300000
#  batch loss:  0.092
#  running loss:  8.772
#  batch error:  7.575
#  batch avg Phy Q value:  7.835
#  batch avg DQN Q value:  9.257
#  batch mean DQN best action probability:  30.351 %
# ----------
# Epoch 69000/300000
#  batch loss:  0.058
#  running loss:  8.748
#  batch error:  5.624
#  batch avg Phy Q value:  7.802
#  batch avg DQN Q value:  9.155
#  batch mean DQN best action probability:  29.574 %
# ----------
# Epoch 70000/300000
#  batch loss:  0.086
#  running loss:  8.724
#  batch error:  5.708
#  batch avg Phy Q value:  8.133
#  batch avg DQN Q value:  9.466
#  batch mean DQN best action probability:  33.01 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 12.918
# DQN WIS: 12.459
# ----------
# val
# DQN WDR: 12.888
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: -8.211
# DQN WIS: -8.18
# ----------
# ----------
# Saving interim Model 70000
# ----------
# Epoch 71000/300000
#  batch loss:  0.093
#  running loss:  8.703
#  batch error:  7.35
#  batch avg Phy Q value:  7.8
#  batch avg DQN Q value:  9.052
#  batch mean DQN best action probability:  31.505 %
# ----------
# Epoch 72000/300000
#  batch loss:  0.1
#  running loss:  8.682
#  batch error:  6.887
#  batch avg Phy Q value:  7.703
#  batch avg DQN Q value:  9.12
#  batch mean DQN best action probability:  31.489 %
# ----------
# Epoch 73000/300000
#  batch loss:  0.117
#  running loss:  8.66
#  batch error:  8.258
#  batch avg Phy Q value:  7.425
#  batch avg DQN Q value:  9.338
#  batch mean DQN best action probability:  31.738 %
# ----------
# Epoch 74000/300000
#  batch loss:  0.08
#  running loss:  8.638
#  batch error:  7.275
#  batch avg Phy Q value:  7.396
#  batch avg DQN Q value:  9.45
#  batch mean DQN best action probability:  35.164 %
# ----------
# Epoch 75000/300000
#  batch loss:  0.12
#  running loss:  8.616
#  batch error:  8.048
#  batch avg Phy Q value:  7.605
#  batch avg DQN Q value:  9.09
#  batch mean DQN best action probability:  30.814 %
# ----------
# Epoch 76000/300000
#  batch loss:  0.085
#  running loss:  8.593
#  batch error:  7.145
#  batch avg Phy Q value:  8.269
#  batch avg DQN Q value:  9.387
#  batch mean DQN best action probability:  33.142 %
# ----------
# Epoch 77000/300000
#  batch loss:  0.09
#  running loss:  8.572
#  batch error:  6.91
#  batch avg Phy Q value:  7.941
#  batch avg DQN Q value:  9.143
#  batch mean DQN best action probability:  30.527 %
# ----------
# Epoch 78000/300000
#  batch loss:  0.086
#  running loss:  8.551
#  batch error:  6.555
#  batch avg Phy Q value:  7.927
#  batch avg DQN Q value:  9.237
#  batch mean DQN best action probability:  34.099 %
# ----------
# Epoch 79000/300000
#  batch loss:  0.11
#  running loss:  8.531
#  batch error:  7.9
#  batch avg Phy Q value:  8.35
#  batch avg DQN Q value:  9.225
#  batch mean DQN best action probability:  30.347 %
# ----------
# Epoch 80000/300000
#  batch loss:  0.081
#  running loss:  8.51
#  batch error:  6.813
#  batch avg Phy Q value:  8.267
#  batch avg DQN Q value:  9.299
#  batch mean DQN best action probability:  31.98 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 12.019
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.195
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: -1.295
# DQN WIS: -2.278
# ----------
# ----------
# Saving interim Model 80000
# ----------
# Epoch 81000/300000
#  batch loss:  0.111
#  running loss:  8.489
#  batch error:  5.944
#  batch avg Phy Q value:  7.706
#  batch avg DQN Q value:  9.233
#  batch mean DQN best action probability:  31.558 %
# ----------
# Epoch 82000/300000
#  batch loss:  0.095
#  running loss:  8.468
#  batch error:  6.566
#  batch avg Phy Q value:  8.168
#  batch avg DQN Q value:  9.502
#  batch mean DQN best action probability:  32.193 %
# ----------
# Epoch 83000/300000
#  batch loss:  0.059
#  running loss:  8.449
#  batch error:  5.817
#  batch avg Phy Q value:  8.253
#  batch avg DQN Q value:  9.446
#  batch mean DQN best action probability:  30.198 %
# ----------
# Epoch 84000/300000
#  batch loss:  0.099
#  running loss:  8.429
#  batch error:  6.734
#  batch avg Phy Q value:  7.934
#  batch avg DQN Q value:  9.47
#  batch mean DQN best action probability:  33.543 %
# ----------
# Epoch 85000/300000
#  batch loss:  0.049
#  running loss:  8.409
#  batch error:  5.338
#  batch avg Phy Q value:  8.05
#  batch avg DQN Q value:  9.262
#  batch mean DQN best action probability:  30.929 %
# ----------
# Epoch 86000/300000
#  batch loss:  0.103
#  running loss:  8.388
#  batch error:  7.42
#  batch avg Phy Q value:  7.865
#  batch avg DQN Q value:  9.421
#  batch mean DQN best action probability:  30.932 %
# ----------
# Epoch 87000/300000
#  batch loss:  0.124
#  running loss:  8.369
#  batch error:  8.09
#  batch avg Phy Q value:  7.863
#  batch avg DQN Q value:  9.403
#  batch mean DQN best action probability:  28.294 %
# ----------
# Epoch 88000/300000
#  batch loss:  0.111
#  running loss:  8.348
#  batch error:  7.405
#  batch avg Phy Q value:  8.086
#  batch avg DQN Q value:  9.876
#  batch mean DQN best action probability:  36.354 %
# ----------
# Epoch 89000/300000
#  batch loss:  0.103
#  running loss:  8.33
#  batch error:  7.857
#  batch avg Phy Q value:  7.598
#  batch avg DQN Q value:  9.288
#  batch mean DQN best action probability:  33.081 %
# ----------
# Epoch 90000/300000
#  batch loss:  0.091
#  running loss:  8.313
#  batch error:  6.734
#  batch avg Phy Q value:  7.607
#  batch avg DQN Q value:  9.627
#  batch mean DQN best action probability:  33.399 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 10.865
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.154
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: -4.608
# DQN WIS: -6.426
# ----------
# ----------
# Saving interim Model 90000
# ----------
# Epoch 91000/300000
#  batch loss:  0.044
#  running loss:  8.294
#  batch error:  4.906
#  batch avg Phy Q value:  8.144
#  batch avg DQN Q value:  9.269
#  batch mean DQN best action probability:  28.472 %
# ----------
# Epoch 92000/300000
#  batch loss:  0.09
#  running loss:  8.276
#  batch error:  7.175
#  batch avg Phy Q value:  7.838
#  batch avg DQN Q value:  9.527
#  batch mean DQN best action probability:  30.075 %
# ----------
# Epoch 93000/300000
#  batch loss:  0.106
#  running loss:  8.258
#  batch error:  6.786
#  batch avg Phy Q value:  8.042
#  batch avg DQN Q value:  9.369
#  batch mean DQN best action probability:  30.08 %
# ----------
# Epoch 94000/300000
#  batch loss:  0.091
#  running loss:  8.24
#  batch error:  6.736
#  batch avg Phy Q value:  7.827
#  batch avg DQN Q value:  9.534
#  batch mean DQN best action probability:  31.788 %
# ----------
# Epoch 95000/300000
#  batch loss:  0.606
#  running loss:  8.221
#  batch error:  7.882
#  batch avg Phy Q value:  8.039
#  batch avg DQN Q value:  9.349
#  batch mean DQN best action probability:  29.767 %
# ----------
# Epoch 96000/300000
#  batch loss:  0.073
#  running loss:  8.204
#  batch error:  5.837
#  batch avg Phy Q value:  7.992
#  batch avg DQN Q value:  9.077
#  batch mean DQN best action probability:  29.536 %
# ----------
# Epoch 97000/300000
#  batch loss:  0.054
#  running loss:  8.188
#  batch error:  4.891
#  batch avg Phy Q value:  8.085
#  batch avg DQN Q value:  9.335
#  batch mean DQN best action probability:  33.675 %
# ----------
# Epoch 98000/300000
#  batch loss:  0.061
#  running loss:  8.171
#  batch error:  5.301
#  batch avg Phy Q value:  8.084
#  batch avg DQN Q value:  9.252
#  batch mean DQN best action probability:  31.9 %
# ----------
# Epoch 99000/300000
#  batch loss:  0.071
#  running loss:  8.153
#  batch error:  6.437
#  batch avg Phy Q value:  8.119
#  batch avg DQN Q value:  9.355
#  batch mean DQN best action probability:  29.942 %
# ----------
# Epoch 100000/300000
#  batch loss:  0.075
#  running loss:  8.138
#  batch error:  6.417
#  batch avg Phy Q value:  7.804
#  batch avg DQN Q value:  9.418
#  batch mean DQN best action probability:  33.646 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 12.353
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.101
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: 18.398
# DQN WIS: 12.642
# ----------
# ----------
# Saving interim Model 100000
# ----------
# Epoch 101000/300000
#  batch loss:  0.077
#  running loss:  8.122
#  batch error:  6.407
#  batch avg Phy Q value:  7.747
#  batch avg DQN Q value:  9.219
#  batch mean DQN best action probability:  29.598 %
# ----------
# Epoch 102000/300000
#  batch loss:  0.077
#  running loss:  8.106
#  batch error:  6.003
#  batch avg Phy Q value:  7.836
#  batch avg DQN Q value:  9.344
#  batch mean DQN best action probability:  29.833 %
# ----------
# Epoch 103000/300000
#  batch loss:  0.092
#  running loss:  8.09
#  batch error:  7.114
#  batch avg Phy Q value:  7.556
#  batch avg DQN Q value:  9.476
#  batch mean DQN best action probability:  30.184 %
# ----------
# Epoch 104000/300000
#  batch loss:  0.045
#  running loss:  8.073
#  batch error:  5.465
#  batch avg Phy Q value:  7.943
#  batch avg DQN Q value:  9.442
#  batch mean DQN best action probability:  32.477 %
# ----------
# Epoch 105000/300000
#  batch loss:  0.046
#  running loss:  8.06
#  batch error:  5.065
#  batch avg Phy Q value:  8.208
#  batch avg DQN Q value:  9.606
#  batch mean DQN best action probability:  36.511 %
# ----------
# Epoch 106000/300000
#  batch loss:  0.093
#  running loss:  8.045
#  batch error:  6.753
#  batch avg Phy Q value:  7.992
#  batch avg DQN Q value:  9.546
#  batch mean DQN best action probability:  33.22 %
# ----------
# Epoch 107000/300000
#  batch loss:  0.056
#  running loss:  8.029
#  batch error:  5.14
#  batch avg Phy Q value:  8.472
#  batch avg DQN Q value:  9.792
#  batch mean DQN best action probability:  35.843 %
# ----------
# Epoch 108000/300000
#  batch loss:  0.058
#  running loss:  8.014
#  batch error:  5.577
#  batch avg Phy Q value:  8.401
#  batch avg DQN Q value:  9.953
#  batch mean DQN best action probability:  34.674 %
# ----------
# Epoch 109000/300000
#  batch loss:  0.07
#  running loss:  7.999
#  batch error:  5.384
#  batch avg Phy Q value:  8.967
#  batch avg DQN Q value:  9.919
#  batch mean DQN best action probability:  36.612 %
# ----------
# Epoch 110000/300000
#  batch loss:  0.099
#  running loss:  7.983
#  batch error:  6.915
#  batch avg Phy Q value:  8.021
#  batch avg DQN Q value:  9.852
#  batch mean DQN best action probability:  36.903 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.963
# DQN WIS: 12.637
# ----------
# val
# DQN WDR: 13.66
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: -11.642
# DQN WIS: -12.454
# ----------
# ----------
# Saving interim Model 110000
# ----------
# Epoch 111000/300000
#  batch loss:  0.096
#  running loss:  7.969
#  batch error:  6.892
#  batch avg Phy Q value:  8.111
#  batch avg DQN Q value:  9.697
#  batch mean DQN best action probability:  32.221 %
# ----------
# Epoch 112000/300000
#  batch loss:  0.071
#  running loss:  7.954
#  batch error:  5.571
#  batch avg Phy Q value:  8.46
#  batch avg DQN Q value:  9.838
#  batch mean DQN best action probability:  34.858 %
# ----------
# Epoch 113000/300000
#  batch loss:  0.078
#  running loss:  7.94
#  batch error:  6.203
#  batch avg Phy Q value:  8.264
#  batch avg DQN Q value:  9.863
#  batch mean DQN best action probability:  33.309 %
# ----------
# Epoch 114000/300000
#  batch loss:  0.065
#  running loss:  7.924
#  batch error:  5.165
#  batch avg Phy Q value:  8.562
#  batch avg DQN Q value:  9.992
#  batch mean DQN best action probability:  34.156 %
# ----------
# Epoch 115000/300000
#  batch loss:  0.096
#  running loss:  7.908
#  batch error:  6.676
#  batch avg Phy Q value:  8.713
#  batch avg DQN Q value:  10.124
#  batch mean DQN best action probability:  35.616 %
# ----------
# Epoch 116000/300000
#  batch loss:  0.081
#  running loss:  7.892
#  batch error:  5.815
#  batch avg Phy Q value:  8.92
#  batch avg DQN Q value:  10.123
#  batch mean DQN best action probability:  34.64 %
# ----------
# Epoch 117000/300000
#  batch loss:  0.083
#  running loss:  7.877
#  batch error:  6.499
#  batch avg Phy Q value:  8.672
#  batch avg DQN Q value:  10.245
#  batch mean DQN best action probability:  35.852 %
# ----------
# Epoch 118000/300000
#  batch loss:  0.05
#  running loss:  7.863
#  batch error:  4.893
#  batch avg Phy Q value:  8.669
#  batch avg DQN Q value:  9.721
#  batch mean DQN best action probability:  31.046 %
# ----------
# Epoch 119000/300000
#  batch loss:  0.091
#  running loss:  7.849
#  batch error:  5.73
#  batch avg Phy Q value:  8.623
#  batch avg DQN Q value:  9.939
#  batch mean DQN best action probability:  31.517 %
# ----------
# Epoch 120000/300000
#  batch loss:  0.075
#  running loss:  7.835
#  batch error:  5.16
#  batch avg Phy Q value:  8.704
#  batch avg DQN Q value:  9.858
#  batch mean DQN best action probability:  30.895 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.977
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.444
# DQN WIS: 12.641
# ----------
# test
# DQN WDR: 15.147
# DQN WIS: 11.175
# ----------
# ----------
# Saving interim Model 120000
# ----------
# Epoch 121000/300000
#  batch loss:  0.123
#  running loss:  7.821
#  batch error:  8.737
#  batch avg Phy Q value:  8.11
#  batch avg DQN Q value:  10.015
#  batch mean DQN best action probability:  34.002 %
# ----------
# Epoch 122000/300000
#  batch loss:  0.051
#  running loss:  7.807
#  batch error:  5.019
#  batch avg Phy Q value:  8.656
#  batch avg DQN Q value:  9.904
#  batch mean DQN best action probability:  31.015 %
# ----------
# Epoch 123000/300000
#  batch loss:  0.048
#  running loss:  7.792
#  batch error:  4.402
#  batch avg Phy Q value:  8.411
#  batch avg DQN Q value:  10.154
#  batch mean DQN best action probability:  33.481 %
# ----------
# Epoch 124000/300000
#  batch loss:  0.087
#  running loss:  7.778
#  batch error:  6.754
#  batch avg Phy Q value:  8.149
#  batch avg DQN Q value:  10.0
#  batch mean DQN best action probability:  33.791 %
# ----------
# Epoch 125000/300000
#  batch loss:  0.095
#  running loss:  7.766
#  batch error:  6.458
#  batch avg Phy Q value:  7.61
#  batch avg DQN Q value:  9.842
#  batch mean DQN best action probability:  31.553 %
# ----------
# Epoch 126000/300000
#  batch loss:  0.056
#  running loss:  7.753
#  batch error:  5.509
#  batch avg Phy Q value:  8.153
#  batch avg DQN Q value:  9.988
#  batch mean DQN best action probability:  36.141 %
# ----------
# Epoch 127000/300000
#  batch loss:  0.078
#  running loss:  7.74
#  batch error:  6.688
#  batch avg Phy Q value:  7.825
#  batch avg DQN Q value:  9.884
#  batch mean DQN best action probability:  36.512 %
# ----------
# Epoch 128000/300000
#  batch loss:  0.059
#  running loss:  7.727
#  batch error:  5.472
#  batch avg Phy Q value:  8.392
#  batch avg DQN Q value:  9.948
#  batch mean DQN best action probability:  35.294 %
# ----------
# Epoch 129000/300000
#  batch loss:  0.053
#  running loss:  7.715
#  batch error:  5.123
#  batch avg Phy Q value:  8.324
#  batch avg DQN Q value:  9.861
#  batch mean DQN best action probability:  32.187 %
# ----------
# Epoch 130000/300000
#  batch loss:  0.077
#  running loss:  7.701
#  batch error:  5.471
#  batch avg Phy Q value:  8.793
#  batch avg DQN Q value:  9.961
#  batch mean DQN best action probability:  31.276 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 12.282
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 14.759
# DQN WIS: 12.636
# ----------
# test
# DQN WDR: 16.658
# DQN WIS: 11.881
# ----------
# ----------
# Saving interim Model 130000
# ----------
# Epoch 131000/300000
#  batch loss:  0.076
#  running loss:  7.687
#  batch error:  6.025
#  batch avg Phy Q value:  8.418
#  batch avg DQN Q value:  9.942
#  batch mean DQN best action probability:  32.048 %
# ----------
# Epoch 132000/300000
#  batch loss:  0.396
#  running loss:  7.673
#  batch error:  5.31
#  batch avg Phy Q value:  8.02
#  batch avg DQN Q value:  9.943
#  batch mean DQN best action probability:  29.94 %
# ----------
# Epoch 133000/300000
#  batch loss:  0.066
#  running loss:  7.661
#  batch error:  5.467
#  batch avg Phy Q value:  8.222
#  batch avg DQN Q value:  9.832
#  batch mean DQN best action probability:  29.136 %
# ----------
# Epoch 134000/300000
#  batch loss:  0.049
#  running loss:  7.648
#  batch error:  5.014
#  batch avg Phy Q value:  8.541
#  batch avg DQN Q value:  9.952
#  batch mean DQN best action probability:  33.05 %
# ----------
# Epoch 135000/300000
#  batch loss:  0.046
#  running loss:  7.635
#  batch error:  4.372
#  batch avg Phy Q value:  8.791
#  batch avg DQN Q value:  10.269
#  batch mean DQN best action probability:  36.064 %
# ----------
# Epoch 136000/300000
#  batch loss:  0.054
#  running loss:  7.623
#  batch error:  4.99
#  batch avg Phy Q value:  8.306
#  batch avg DQN Q value:  10.061
#  batch mean DQN best action probability:  34.889 %
# ----------
# Epoch 137000/300000
#  batch loss:  0.089
#  running loss:  7.611
#  batch error:  6.095
#  batch avg Phy Q value:  8.389
#  batch avg DQN Q value:  9.93
#  batch mean DQN best action probability:  32.037 %
# ----------
# Epoch 138000/300000
#  batch loss:  0.097
#  running loss:  7.599
#  batch error:  7.105
#  batch avg Phy Q value:  8.389
#  batch avg DQN Q value:  9.832
#  batch mean DQN best action probability:  29.595 %
# ----------
# Epoch 139000/300000
#  batch loss:  0.066
#  running loss:  7.586
#  batch error:  5.36
#  batch avg Phy Q value:  8.582
#  batch avg DQN Q value:  10.025
#  batch mean DQN best action probability:  33.043 %
# ----------
# Epoch 140000/300000
#  batch loss:  0.073
#  running loss:  7.573
#  batch error:  6.459
#  batch avg Phy Q value:  8.21
#  batch avg DQN Q value:  10.102
#  batch mean DQN best action probability:  30.634 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.136
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 14.23
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: -5.787
# DQN WIS: -6.861
# ----------
# ----------
# Saving interim Model 140000
# ----------
# Epoch 141000/300000
#  batch loss:  0.041
#  running loss:  7.561
#  batch error:  4.874
#  batch avg Phy Q value:  8.434
#  batch avg DQN Q value:  10.008
#  batch mean DQN best action probability:  32.143 %
# ----------
# Epoch 142000/300000
#  batch loss:  0.141
#  running loss:  7.549
#  batch error:  6.457
#  batch avg Phy Q value:  8.212
#  batch avg DQN Q value:  9.806
#  batch mean DQN best action probability:  33.888 %
# ----------
# Epoch 143000/300000
#  batch loss:  0.064
#  running loss:  7.538
#  batch error:  5.434
#  batch avg Phy Q value:  8.492
#  batch avg DQN Q value:  10.062
#  batch mean DQN best action probability:  34.562 %
# ----------
# Epoch 144000/300000
#  batch loss:  0.084
#  running loss:  7.525
#  batch error:  6.445
#  batch avg Phy Q value:  8.677
#  batch avg DQN Q value:  9.957
#  batch mean DQN best action probability:  31.597 %
# ----------
# Epoch 145000/300000
#  batch loss:  0.061
#  running loss:  7.513
#  batch error:  5.172
#  batch avg Phy Q value:  8.615
#  batch avg DQN Q value:  10.102
#  batch mean DQN best action probability:  31.154 %
# ----------
# Epoch 146000/300000
#  batch loss:  0.1
#  running loss:  7.501
#  batch error:  6.927
#  batch avg Phy Q value:  8.304
#  batch avg DQN Q value:  10.134
#  batch mean DQN best action probability:  35.491 %
# ----------
# Epoch 147000/300000
#  batch loss:  0.083
#  running loss:  7.489
#  batch error:  5.621
#  batch avg Phy Q value:  8.561
#  batch avg DQN Q value:  10.187
#  batch mean DQN best action probability:  33.672 %
# ----------
# Epoch 148000/300000
#  batch loss:  0.04
#  running loss:  7.478
#  batch error:  4.448
#  batch avg Phy Q value:  8.475
#  batch avg DQN Q value:  10.01
#  batch mean DQN best action probability:  32.57 %
# ----------
# Epoch 149000/300000
#  batch loss:  0.057
#  running loss:  7.466
#  batch error:  5.1
#  batch avg Phy Q value:  8.437
#  batch avg DQN Q value:  10.025
#  batch mean DQN best action probability:  30.787 %
# ----------
# Epoch 150000/300000
#  batch loss:  0.144
#  running loss:  7.455
#  batch error:  7.183
#  batch avg Phy Q value:  8.135
#  batch avg DQN Q value:  9.935
#  batch mean DQN best action probability:  34.898 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 10.946
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.229
# DQN WIS: 12.632
# ----------
# test
# DQN WDR: 12.051
# DQN WIS: 11.892
# ----------
# ----------
# Saving interim Model 150000
# ----------
# Epoch 151000/300000
#  batch loss:  0.07
#  running loss:  7.444
#  batch error:  5.667
#  batch avg Phy Q value:  8.225
#  batch avg DQN Q value:  9.648
#  batch mean DQN best action probability:  30.483 %
# ----------
# Epoch 152000/300000
#  batch loss:  0.048
#  running loss:  7.434
#  batch error:  4.512
#  batch avg Phy Q value:  7.946
#  batch avg DQN Q value:  9.549
#  batch mean DQN best action probability:  30.389 %
# ----------
# Epoch 153000/300000
#  batch loss:  0.046
#  running loss:  7.423
#  batch error:  4.764
#  batch avg Phy Q value:  8.018
#  batch avg DQN Q value:  9.517
#  batch mean DQN best action probability:  31.17 %
# ----------
# Epoch 154000/300000
#  batch loss:  0.073
#  running loss:  7.413
#  batch error:  5.695
#  batch avg Phy Q value:  8.38
#  batch avg DQN Q value:  9.607
#  batch mean DQN best action probability:  29.873 %
# ----------
# Epoch 155000/300000
#  batch loss:  0.067
#  running loss:  7.403
#  batch error:  5.713
#  batch avg Phy Q value:  8.111
#  batch avg DQN Q value:  9.844
#  batch mean DQN best action probability:  35.213 %
# ----------
# Epoch 156000/300000
#  batch loss:  0.077
#  running loss:  7.393
#  batch error:  6.223
#  batch avg Phy Q value:  8.057
#  batch avg DQN Q value:  9.633
#  batch mean DQN best action probability:  33.926 %
# ----------
# Epoch 157000/300000
#  batch loss:  0.031
#  running loss:  7.382
#  batch error:  3.703
#  batch avg Phy Q value:  7.631
#  batch avg DQN Q value:  9.751
#  batch mean DQN best action probability:  33.728 %
# ----------
# Epoch 158000/300000
#  batch loss:  0.119
#  running loss:  7.372
#  batch error:  7.902
#  batch avg Phy Q value:  8.017
#  batch avg DQN Q value:  9.827
#  batch mean DQN best action probability:  36.048 %
# ----------
# Epoch 159000/300000
#  batch loss:  0.05
#  running loss:  7.361
#  batch error:  4.828
#  batch avg Phy Q value:  8.399
#  batch avg DQN Q value:  9.949
#  batch mean DQN best action probability:  36.874 %
# ----------
# Epoch 160000/300000
#  batch loss:  0.036
#  running loss:  7.351
#  batch error:  3.665
#  batch avg Phy Q value:  8.588
#  batch avg DQN Q value:  10.112
#  batch mean DQN best action probability:  35.022 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.307
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.93
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: 17.2
# DQN WIS: 12.608
# ----------
# ----------
# Saving interim Model 160000
# ----------
# Epoch 161000/300000
#  batch loss:  0.076
#  running loss:  7.341
#  batch error:  6.082
#  batch avg Phy Q value:  7.725
#  batch avg DQN Q value:  9.714
#  batch mean DQN best action probability:  30.914 %
# ----------
# Epoch 162000/300000
#  batch loss:  0.082
#  running loss:  7.331
#  batch error:  6.27
#  batch avg Phy Q value:  8.132
#  batch avg DQN Q value:  9.921
#  batch mean DQN best action probability:  36.231 %
# ----------
# Epoch 163000/300000
#  batch loss:  0.09
#  running loss:  7.321
#  batch error:  5.883
#  batch avg Phy Q value:  8.205
#  batch avg DQN Q value:  9.924
#  batch mean DQN best action probability:  35.237 %
# ----------
# Epoch 164000/300000
#  batch loss:  0.039
#  running loss:  7.311
#  batch error:  4.36
#  batch avg Phy Q value:  8.247
#  batch avg DQN Q value:  10.057
#  batch mean DQN best action probability:  36.0 %
# ----------
# Epoch 165000/300000
#  batch loss:  0.07
#  running loss:  7.301
#  batch error:  5.411
#  batch avg Phy Q value:  8.755
#  batch avg DQN Q value:  10.081
#  batch mean DQN best action probability:  32.937 %
# ----------
# Epoch 166000/300000
#  batch loss:  0.125
#  running loss:  7.291
#  batch error:  7.823
#  batch avg Phy Q value:  8.026
#  batch avg DQN Q value:  9.852
#  batch mean DQN best action probability:  33.167 %
# ----------
# Epoch 167000/300000
#  batch loss:  0.064
#  running loss:  7.281
#  batch error:  5.628
#  batch avg Phy Q value:  8.275
#  batch avg DQN Q value:  9.916
#  batch mean DQN best action probability:  31.966 %
# ----------
# Epoch 168000/300000
#  batch loss:  0.079
#  running loss:  7.271
#  batch error:  5.688
#  batch avg Phy Q value:  7.837
#  batch avg DQN Q value:  9.884
#  batch mean DQN best action probability:  34.464 %
# ----------
# Epoch 169000/300000
#  batch loss:  0.074
#  running loss:  7.262
#  batch error:  5.533
#  batch avg Phy Q value:  8.446
#  batch avg DQN Q value:  10.226
#  batch mean DQN best action probability:  38.877 %
# ----------
# Epoch 170000/300000
#  batch loss:  0.024
#  running loss:  7.252
#  batch error:  3.607
#  batch avg Phy Q value:  8.574
#  batch avg DQN Q value:  10.078
#  batch mean DQN best action probability:  33.79 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.68
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.083
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: 17.498
# DQN WIS: 12.631
# ----------
# ----------
# Saving interim Model 170000
# ----------
# Epoch 171000/300000
#  batch loss:  0.093
#  running loss:  7.242
#  batch error:  6.8
#  batch avg Phy Q value:  8.449
#  batch avg DQN Q value:  10.352
#  batch mean DQN best action probability:  38.312 %
# ----------
# Epoch 172000/300000
#  batch loss:  0.07
#  running loss:  7.232
#  batch error:  5.494
#  batch avg Phy Q value:  8.468
#  batch avg DQN Q value:  10.353
#  batch mean DQN best action probability:  36.508 %
# ----------
# Epoch 173000/300000
#  batch loss:  0.045
#  running loss:  7.222
#  batch error:  4.418
#  batch avg Phy Q value:  8.775
#  batch avg DQN Q value:  10.274
#  batch mean DQN best action probability:  36.473 %
# ----------
# Epoch 174000/300000
#  batch loss:  0.039
#  running loss:  7.212
#  batch error:  4.302
#  batch avg Phy Q value:  8.829
#  batch avg DQN Q value:  10.505
#  batch mean DQN best action probability:  39.347 %
# ----------
# Epoch 175000/300000
#  batch loss:  0.085
#  running loss:  7.202
#  batch error:  5.808
#  batch avg Phy Q value:  8.368
#  batch avg DQN Q value:  10.36
#  batch mean DQN best action probability:  37.045 %
# ----------
# Epoch 176000/300000
#  batch loss:  0.068
#  running loss:  7.193
#  batch error:  6.126
#  batch avg Phy Q value:  8.194
#  batch avg DQN Q value:  10.534
#  batch mean DQN best action probability:  40.878 %
# ----------
# Epoch 177000/300000
#  batch loss:  0.071
#  running loss:  7.183
#  batch error:  4.755
#  batch avg Phy Q value:  8.915
#  batch avg DQN Q value:  10.421
#  batch mean DQN best action probability:  36.08 %
# ----------
# Epoch 178000/300000
#  batch loss:  0.113
#  running loss:  7.173
#  batch error:  6.702
#  batch avg Phy Q value:  7.928
#  batch avg DQN Q value:  10.308
#  batch mean DQN best action probability:  38.401 %
# ----------
# Epoch 179000/300000
#  batch loss:  0.402
#  running loss:  7.163
#  batch error:  7.346
#  batch avg Phy Q value:  8.823
#  batch avg DQN Q value:  10.436
#  batch mean DQN best action probability:  36.869 %
# ----------
# Epoch 180000/300000
#  batch loss:  0.031
#  running loss:  7.154
#  batch error:  3.96
#  batch avg Phy Q value:  8.469
#  batch avg DQN Q value:  10.271
#  batch mean DQN best action probability:  34.173 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.459
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.724
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: 16.191
# DQN WIS: 12.276
# ----------
# ----------
# Saving interim Model 180000
# ----------
# Epoch 181000/300000
#  batch loss:  0.051
#  running loss:  7.144
#  batch error:  4.809
#  batch avg Phy Q value:  8.586
#  batch avg DQN Q value:  10.241
#  batch mean DQN best action probability:  32.117 %
# ----------
# Epoch 182000/300000
#  batch loss:  0.069
#  running loss:  7.135
#  batch error:  5.414
#  batch avg Phy Q value:  8.619
#  batch avg DQN Q value:  10.428
#  batch mean DQN best action probability:  34.034 %
# ----------
# Epoch 183000/300000
#  batch loss:  0.085
#  running loss:  7.126
#  batch error:  5.253
#  batch avg Phy Q value:  8.771
#  batch avg DQN Q value:  10.267
#  batch mean DQN best action probability:  33.368 %
# ----------
# Epoch 184000/300000
#  batch loss:  0.103
#  running loss:  7.116
#  batch error:  6.824
#  batch avg Phy Q value:  8.523
#  batch avg DQN Q value:  10.391
#  batch mean DQN best action probability:  35.738 %
# ----------
# Epoch 185000/300000
#  batch loss:  0.085
#  running loss:  7.106
#  batch error:  5.74
#  batch avg Phy Q value:  8.446
#  batch avg DQN Q value:  10.394
#  batch mean DQN best action probability:  28.897 %
# ----------
# Epoch 186000/300000
#  batch loss:  0.063
#  running loss:  7.097
#  batch error:  5.159
#  batch avg Phy Q value:  8.676
#  batch avg DQN Q value:  10.323
#  batch mean DQN best action probability:  31.471 %
# ----------
# Epoch 187000/300000
#  batch loss:  0.05
#  running loss:  7.088
#  batch error:  4.598
#  batch avg Phy Q value:  8.965
#  batch avg DQN Q value:  10.298
#  batch mean DQN best action probability:  32.601 %
# ----------
# Epoch 188000/300000
#  batch loss:  0.083
#  running loss:  7.078
#  batch error:  6.115
#  batch avg Phy Q value:  8.691
#  batch avg DQN Q value:  10.485
#  batch mean DQN best action probability:  34.394 %
# ----------
# Epoch 189000/300000
#  batch loss:  0.051
#  running loss:  7.068
#  batch error:  4.68
#  batch avg Phy Q value:  8.738
#  batch avg DQN Q value:  10.415
#  batch mean DQN best action probability:  35.885 %
# ----------
# Epoch 190000/300000
#  batch loss:  0.089
#  running loss:  7.059
#  batch error:  6.377
#  batch avg Phy Q value:  8.612
#  batch avg DQN Q value:  10.77
#  batch mean DQN best action probability:  37.75 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 12.22
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.787
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: 18.568
# DQN WIS: 12.637
# ----------
# ----------
# Saving interim Model 190000
# ----------
# Epoch 191000/300000
#  batch loss:  0.107
#  running loss:  7.05
#  batch error:  6.498
#  batch avg Phy Q value:  8.617
#  batch avg DQN Q value:  10.293
#  batch mean DQN best action probability:  31.495 %
# ----------
# Epoch 192000/300000
#  batch loss:  0.07
#  running loss:  7.041
#  batch error:  5.417
#  batch avg Phy Q value:  8.798
#  batch avg DQN Q value:  10.388
#  batch mean DQN best action probability:  36.305 %
# ----------
# Epoch 193000/300000
#  batch loss:  0.059
#  running loss:  7.033
#  batch error:  5.258
#  batch avg Phy Q value:  8.533
#  batch avg DQN Q value:  10.496
#  batch mean DQN best action probability:  37.378 %
# ----------
# Epoch 194000/300000
#  batch loss:  0.066
#  running loss:  7.024
#  batch error:  5.219
#  batch avg Phy Q value:  8.761
#  batch avg DQN Q value:  10.412
#  batch mean DQN best action probability:  35.872 %
# ----------
# Epoch 195000/300000
#  batch loss:  0.033
#  running loss:  7.016
#  batch error:  4.127
#  batch avg Phy Q value:  8.572
#  batch avg DQN Q value:  10.458
#  batch mean DQN best action probability:  37.278 %
# ----------
# Epoch 196000/300000
#  batch loss:  0.055
#  running loss:  7.007
#  batch error:  4.445
#  batch avg Phy Q value:  8.636
#  batch avg DQN Q value:  10.272
#  batch mean DQN best action probability:  35.654 %
# ----------
# Epoch 197000/300000
#  batch loss:  0.071
#  running loss:  6.998
#  batch error:  5.835
#  batch avg Phy Q value:  8.722
#  batch avg DQN Q value:  10.426
#  batch mean DQN best action probability:  35.875 %
# ----------
# Epoch 198000/300000
#  batch loss:  0.089
#  running loss:  6.99
#  batch error:  6.238
#  batch avg Phy Q value:  8.527
#  batch avg DQN Q value:  10.491
#  batch mean DQN best action probability:  34.399 %
# ----------
# Epoch 199000/300000
#  batch loss:  0.043
#  running loss:  6.981
#  batch error:  4.652
#  batch avg Phy Q value:  9.036
#  batch avg DQN Q value:  10.65
#  batch mean DQN best action probability:  39.471 %
# ----------
# Epoch 200000/300000
#  batch loss:  0.083
#  running loss:  6.973
#  batch error:  5.789
#  batch avg Phy Q value:  8.731
#  batch avg DQN Q value:  10.598
#  batch mean DQN best action probability:  36.118 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 12.341
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.748
# DQN WIS: 12.644
# ----------
# test
# DQN WDR: 17.188
# DQN WIS: 12.571
# ----------
# ----------
# Saving interim Model 200000
# ----------
# Epoch 201000/300000
#  batch loss:  0.073
#  running loss:  6.964
#  batch error:  5.611
#  batch avg Phy Q value:  8.503
#  batch avg DQN Q value:  10.611
#  batch mean DQN best action probability:  38.158 %
# ----------
# Epoch 202000/300000
#  batch loss:  0.053
#  running loss:  6.956
#  batch error:  5.403
#  batch avg Phy Q value:  9.057
#  batch avg DQN Q value:  10.488
#  batch mean DQN best action probability:  33.052 %
# ----------
# Epoch 203000/300000
#  batch loss:  0.066
#  running loss:  6.947
#  batch error:  5.132
#  batch avg Phy Q value:  8.505
#  batch avg DQN Q value:  10.537
#  batch mean DQN best action probability:  35.089 %
# ----------
# Epoch 204000/300000
#  batch loss:  0.059
#  running loss:  6.939
#  batch error:  5.005
#  batch avg Phy Q value:  8.544
#  batch avg DQN Q value:  10.502
#  batch mean DQN best action probability:  35.338 %
# ----------
# Epoch 205000/300000
#  batch loss:  0.07
# ...
# Epoch 234000/300000
#  batch loss:  0.035
#  running loss:  6.713
#  batch error:  4.503
#  batch avg Phy Q value:  8.006
#  batch avg DQN Q value:  10.101
#  batch mean DQN best action probability:  37.512 %
# ----------
# Epoch 235000/300000
#  batch loss:  0.062
#  running loss:  6.706
#  batch error:  5.154
#  batch avg Phy Q value:  7.803
#  batch avg DQN Q value:  10.053
#  batch mean DQN best action probability:  37.336 %
# ----------
# Epoch 236000/300000
#  batch loss:  0.109
#  running loss:  6.699
#  batch error:  6.665
#  batch avg Phy Q value:  8.083
#  batch avg DQN Q value:  9.849
#  batch mean DQN best action probability:  35.358 %
# ----------
# Epoch 237000/300000
#  batch loss:  0.057
#  running loss:  6.693
#  batch error:  5.058
#  batch avg Phy Q value:  8.035
#  batch avg DQN Q value:  10.042
#  batch mean DQN best action probability:  36.355 %
# ----------
# Epoch 238000/300000
#  batch loss:  0.067
#  running loss:  6.686
#  batch error:  4.94
#  batch avg Phy Q value:  8.628
#  batch avg DQN Q value:  10.113
#  batch mean DQN best action probability:  38.047 %
# ----------
# Epoch 239000/300000
#  batch loss:  0.097
#  running loss:  6.679
#  batch error:  7.441
#  batch avg Phy Q value:  7.559
#  batch avg DQN Q value:  10.285
#  batch mean DQN best action probability:  37.805 %
# ----------
# Epoch 240000/300000
#  batch loss:  0.054
#  running loss:  6.672
#  batch error:  5.01
#  batch avg Phy Q value:  8.266
#  batch avg DQN Q value:  10.174
#  batch mean DQN best action probability:  37.758 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 12.745
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 11.113
# DQN WIS: 12.635
# ----------
# test
# DQN WDR: -8.249
# DQN WIS: -10.484
# ----------
# ----------
# Saving interim Model 240000
# ----------
# Epoch 241000/300000
#  batch loss:  0.239
#  running loss:  6.665
#  batch error:  5.568
#  batch avg Phy Q value:  8.409
#  batch avg DQN Q value:  10.324
#  batch mean DQN best action probability:  40.291 %
# ----------
# Epoch 242000/300000
#  batch loss:  0.057
#  running loss:  6.658
#  batch error:  4.828
#  batch avg Phy Q value:  8.136
#  batch avg DQN Q value:  10.225
#  batch mean DQN best action probability:  40.279 %
# ----------
# Epoch 243000/300000
#  batch loss:  0.084
#  running loss:  6.651
#  batch error:  6.558
#  batch avg Phy Q value:  7.886
#  batch avg DQN Q value:  10.101
#  batch mean DQN best action probability:  33.836 %
# ----------
# Epoch 244000/300000
#  batch loss:  0.073
#  running loss:  6.644
#  batch error:  6.224
#  batch avg Phy Q value:  7.716
#  batch avg DQN Q value:  10.162
#  batch mean DQN best action probability:  35.732 %
# ----------
# Epoch 245000/300000
#  batch loss:  0.121
#  running loss:  6.638
#  batch error:  8.035
#  batch avg Phy Q value:  8.161
#  batch avg DQN Q value:  10.21
#  batch mean DQN best action probability:  37.912 %
# ----------
# Epoch 246000/300000
#  batch loss:  0.06
#  running loss:  6.631
#  batch error:  5.023
#  batch avg Phy Q value:  8.571
#  batch avg DQN Q value:  9.943
#  batch mean DQN best action probability:  32.981 %
# ----------
# Epoch 247000/300000
#  batch loss:  0.042
#  running loss:  6.625
#  batch error:  4.773
#  batch avg Phy Q value:  8.391
#  batch avg DQN Q value:  10.25
#  batch mean DQN best action probability:  37.818 %
# ----------
# Epoch 248000/300000
#  batch loss:  0.04
#  running loss:  6.618
#  batch error:  4.272
#  batch avg Phy Q value:  8.385
#  batch avg DQN Q value:  10.147
#  batch mean DQN best action probability:  37.974 %
# ----------
# Epoch 249000/300000
#  batch loss:  0.074
#  running loss:  6.612
#  batch error:  5.373
#  batch avg Phy Q value:  8.243
#  batch avg DQN Q value:  9.91
#  batch mean DQN best action probability:  34.069 %
# ----------
# Epoch 250000/300000
#  batch loss:  0.135
#  running loss:  6.605
#  batch error:  4.82
#  batch avg Phy Q value:  8.494
#  batch avg DQN Q value:  9.943
#  batch mean DQN best action probability:  33.734 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 12.531
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 9.427
# DQN WIS: 9.461
# ----------
# test
# DQN WDR: 16.488
# DQN WIS: 12.473
# ----------
# ----------
# Saving interim Model 250000
# ----------
# Epoch 251000/300000
#  batch loss:  0.021
#  running loss:  6.598
#  batch error:  3.61
#  batch avg Phy Q value:  8.385
#  batch avg DQN Q value:  9.96
#  batch mean DQN best action probability:  32.804 %
# ----------
# Epoch 252000/300000
#  batch loss:  0.059
#  running loss:  6.591
#  batch error:  4.448
#  batch avg Phy Q value:  8.631
#  batch avg DQN Q value:  10.106
#  batch mean DQN best action probability:  33.015 %
# ----------
# Epoch 253000/300000
#  batch loss:  0.078
#  running loss:  6.584
#  batch error:  6.202
#  batch avg Phy Q value:  7.974
#  batch avg DQN Q value:  10.367
#  batch mean DQN best action probability:  35.649 %
# ----------
# Epoch 254000/300000
#  batch loss:  0.042
#  running loss:  6.577
#  batch error:  4.547
#  batch avg Phy Q value:  7.882
#  batch avg DQN Q value:  10.075
#  batch mean DQN best action probability:  35.088 %
# ----------
# Epoch 255000/300000
#  batch loss:  0.05
#  running loss:  6.571
#  batch error:  4.909
#  batch avg Phy Q value:  7.795
#  batch avg DQN Q value:  9.996
#  batch mean DQN best action probability:  35.031 %
# ----------
# Epoch 256000/300000
#  batch loss:  0.038
#  running loss:  6.564
#  batch error:  4.144
#  batch avg Phy Q value:  8.174
#  batch avg DQN Q value:  9.952
#  batch mean DQN best action probability:  33.726 %
# ----------
# Epoch 257000/300000
#  batch loss:  0.069
#  running loss:  6.558
#  batch error:  4.84
#  batch avg Phy Q value:  7.681
#  batch avg DQN Q value:  10.069
#  batch mean DQN best action probability:  36.255 %
# ----------
# Epoch 258000/300000
#  batch loss:  0.061
#  running loss:  6.552
#  batch error:  5.284
#  batch avg Phy Q value:  8.386
#  batch avg DQN Q value:  10.204
#  batch mean DQN best action probability:  37.964 %
# ----------
# Epoch 259000/300000
#  batch loss:  0.046
#  running loss:  6.545
#  batch error:  4.495
#  batch avg Phy Q value:  8.209
#  batch avg DQN Q value:  10.154
#  batch mean DQN best action probability:  36.223 %
# ----------
# Epoch 260000/300000
#  batch loss:  0.058
#  running loss:  6.539
#  batch error:  5.073
#  batch avg Phy Q value:  8.176
#  batch avg DQN Q value:  10.233
#  batch mean DQN best action probability:  37.134 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.792
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 13.505
# DQN WIS: 12.338
# ----------
# test
# DQN WDR: 16.44
# DQN WIS: 12.642
# ----------
# ----------
# Saving interim Model 260000
# ----------
# Epoch 261000/300000
#  batch loss:  0.046
#  running loss:  6.533
#  batch error:  4.767
#  batch avg Phy Q value:  8.049
#  batch avg DQN Q value:  10.191
#  batch mean DQN best action probability:  37.847 %
# ----------
# Epoch 262000/300000
#  batch loss:  0.035
#  running loss:  6.526
#  batch error:  3.845
#  batch avg Phy Q value:  8.119
#  batch avg DQN Q value:  10.046
#  batch mean DQN best action probability:  32.832 %
# ----------
# Epoch 263000/300000
#  batch loss:  0.023
#  running loss:  6.52
#  batch error:  3.72
#  batch avg Phy Q value:  8.836
#  batch avg DQN Q value:  10.056
#  batch mean DQN best action probability:  32.169 %
# ----------
# Epoch 264000/300000
#  batch loss:  0.052
#  running loss:  6.514
#  batch error:  4.322
#  batch avg Phy Q value:  7.697
#  batch avg DQN Q value:  10.132
#  batch mean DQN best action probability:  35.597 %
# ----------
# Epoch 265000/300000
#  batch loss:  0.07
#  running loss:  6.507
#  batch error:  5.424
#  batch avg Phy Q value:  8.377
#  batch avg DQN Q value:  10.119
#  batch mean DQN best action probability:  37.38 %
# ----------
# Epoch 266000/300000
#  batch loss:  0.049
#  running loss:  6.501
#  batch error:  4.513
#  batch avg Phy Q value:  8.671
#  batch avg DQN Q value:  10.434
#  batch mean DQN best action probability:  39.29 %
# ----------
# Epoch 267000/300000
#  batch loss:  0.04
#  running loss:  6.495
#  batch error:  4.604
#  batch avg Phy Q value:  8.35
#  batch avg DQN Q value:  9.9
#  batch mean DQN best action probability:  30.544 %
# ----------
# Epoch 268000/300000
#  batch loss:  0.053
#  running loss:  6.489
#  batch error:  4.517
#  batch avg Phy Q value:  8.494
#  batch avg DQN Q value:  10.447
#  batch mean DQN best action probability:  39.482 %
# ----------
# Epoch 269000/300000
#  batch loss:  0.052
#  running loss:  6.483
#  batch error:  4.466
#  batch avg Phy Q value:  8.272
#  batch avg DQN Q value:  9.831
#  batch mean DQN best action probability:  32.021 %
# ----------
# Epoch 270000/300000
#  batch loss:  0.077
#  running loss:  6.477
#  batch error:  5.845
#  batch avg Phy Q value:  7.935
#  batch avg DQN Q value:  9.945
#  batch mean DQN best action probability:  33.545 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 10.774
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 5.418
# DQN WIS: 0.27
# ----------
# test
# DQN WDR: 10.776
# DQN WIS: 11.483
# ----------
# ----------
# Saving interim Model 270000
# ----------
# Epoch 271000/300000
#  batch loss:  0.075
#  running loss:  6.471
#  batch error:  5.569
#  batch avg Phy Q value:  7.56
#  batch avg DQN Q value:  9.9
#  batch mean DQN best action probability:  30.746 %
# ----------
# Epoch 272000/300000
#  batch loss:  0.047
#  running loss:  6.464
#  batch error:  4.616
#  batch avg Phy Q value:  8.567
#  batch avg DQN Q value:  10.354
#  batch mean DQN best action probability:  35.722 %
# ----------
# Epoch 273000/300000
#  batch loss:  0.049
#  running loss:  6.459
#  batch error:  4.525
#  batch avg Phy Q value:  8.196
#  batch avg DQN Q value:  9.843
#  batch mean DQN best action probability:  33.451 %
# ----------
# Epoch 274000/300000
#  batch loss:  0.076
#  running loss:  6.453
#  batch error:  5.818
#  batch avg Phy Q value:  8.016
#  batch avg DQN Q value:  10.183
#  batch mean DQN best action probability:  36.4 %
# ----------
# Epoch 275000/300000
#  batch loss:  0.043
#  running loss:  6.447
#  batch error:  4.397
#  batch avg Phy Q value:  8.166
#  batch avg DQN Q value:  9.89
#  batch mean DQN best action probability:  35.63 %
# ----------
# Epoch 276000/300000
#  batch loss:  0.116
#  running loss:  6.441
#  batch error:  7.709
#  batch avg Phy Q value:  7.253
#  batch avg DQN Q value:  10.007
#  batch mean DQN best action probability:  36.6 %
# ----------
# Epoch 277000/300000
#  batch loss:  0.053
#  running loss:  6.436
#  batch error:  4.79
#  batch avg Phy Q value:  8.034
#  batch avg DQN Q value:  9.892
#  batch mean DQN best action probability:  30.971 %
# ----------
# Epoch 278000/300000
#  batch loss:  0.037
#  running loss:  6.43
#  batch error:  3.905
#  batch avg Phy Q value:  8.314
#  batch avg DQN Q value:  10.031
#  batch mean DQN best action probability:  36.02 %
# ----------
# Epoch 279000/300000
#  batch loss:  0.056
#  running loss:  6.424
#  batch error:  5.406
#  batch avg Phy Q value:  7.767
#  batch avg DQN Q value:  10.045
#  batch mean DQN best action probability:  32.929 %
# ----------
# Epoch 280000/300000
#  batch loss:  0.092
#  running loss:  6.419
#  batch error:  7.078
#  batch avg Phy Q value:  7.792
#  batch avg DQN Q value:  9.921
#  batch mean DQN best action probability:  34.992 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 4.644
# DQN WIS: 4.206
# ----------
# val
# DQN WDR: 11.462
# DQN WIS: 12.56
# ----------
# test
# DQN WDR: 17.532
# DQN WIS: 12.643
# ----------
# ----------
# Saving interim Model 280000
# ----------
# Epoch 281000/300000
#  batch loss:  0.059
#  running loss:  6.413
#  batch error:  5.455
#  batch avg Phy Q value:  7.819
#  batch avg DQN Q value:  10.108
#  batch mean DQN best action probability:  39.825 %
# ----------
# Epoch 282000/300000
#  batch loss:  0.054
#  running loss:  6.407
#  batch error:  4.668
#  batch avg Phy Q value:  7.878
#  batch avg DQN Q value:  9.893
#  batch mean DQN best action probability:  35.391 %
# ----------
# Epoch 283000/300000
#  batch loss:  0.051
#  running loss:  6.402
#  batch error:  4.965
#  batch avg Phy Q value:  7.383
#  batch avg DQN Q value:  9.663
#  batch mean DQN best action probability:  34.608 %
# ----------
# Epoch 284000/300000
#  batch loss:  0.083
#  running loss:  6.397
#  batch error:  6.263
#  batch avg Phy Q value:  7.462
#  batch avg DQN Q value:  9.48
#  batch mean DQN best action probability:  37.05 %
# ----------
# Epoch 285000/300000
#  batch loss:  0.069
#  running loss:  6.392
#  batch error:  5.616
#  batch avg Phy Q value:  7.267
#  batch avg DQN Q value:  9.572
#  batch mean DQN best action probability:  34.745 %
# ----------
# Epoch 286000/300000
#  batch loss:  0.061
#  running loss:  6.387
#  batch error:  5.468
#  batch avg Phy Q value:  7.522
#  batch avg DQN Q value:  9.645
#  batch mean DQN best action probability:  35.288 %
# ----------
# Epoch 287000/300000
#  batch loss:  0.069
#  running loss:  6.381
#  batch error:  6.172
#  batch avg Phy Q value:  7.255
#  batch avg DQN Q value:  9.665
#  batch mean DQN best action probability:  34.452 %
# ----------
# Epoch 288000/300000
#  batch loss:  0.094
#  running loss:  6.376
#  batch error:  5.994
#  batch avg Phy Q value:  8.104
#  batch avg DQN Q value:  9.683
#  batch mean DQN best action probability:  34.13 %
# ----------
# Epoch 289000/300000
#  batch loss:  0.052
#  running loss:  6.37
#  batch error:  4.814
#  batch avg Phy Q value:  7.102
#  batch avg DQN Q value:  9.677
#  batch mean DQN best action probability:  37.898 %
# ----------
# Epoch 290000/300000
#  batch loss:  0.085
#  running loss:  6.365
#  batch error:  6.615
#  batch avg Phy Q value:  7.455
#  batch avg DQN Q value:  9.568
#  batch mean DQN best action probability:  33.874 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.794
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 9.384
# DQN WIS: 12.628
# ----------
# test
# DQN WDR: 15.204
# DQN WIS: 12.626
# ----------
# ----------
# Saving interim Model 290000
# ----------
# Epoch 291000/300000
#  batch loss:  0.04
#  running loss:  6.359
#  batch error:  4.156
#  batch avg Phy Q value:  7.675
#  batch avg DQN Q value:  9.559
#  batch mean DQN best action probability:  31.982 %
# ----------
# Epoch 292000/300000
#  batch loss:  0.037
#  running loss:  6.354
#  batch error:  4.102
#  batch avg Phy Q value:  7.729
#  batch avg DQN Q value:  9.675
#  batch mean DQN best action probability:  34.595 %
# ----------
# Epoch 293000/300000
#  batch loss:  0.011
#  running loss:  6.349
#  batch error:  2.454
#  batch avg Phy Q value:  7.98
#  batch avg DQN Q value:  9.861
#  batch mean DQN best action probability:  38.241 %
# ----------
# Epoch 294000/300000
#  batch loss:  0.057
#  running loss:  6.343
#  batch error:  4.777
#  batch avg Phy Q value:  8.0
#  batch avg DQN Q value:  10.03
#  batch mean DQN best action probability:  37.937 %
# ----------
# Epoch 295000/300000
#  batch loss:  0.033
#  running loss:  6.338
#  batch error:  3.671
#  batch avg Phy Q value:  7.735
#  batch avg DQN Q value:  9.924
#  batch mean DQN best action probability:  36.083 %
# ----------
# Epoch 296000/300000
#  batch loss:  0.024
#  running loss:  6.332
#  batch error:  3.356
#  batch avg Phy Q value:  8.301
#  batch avg DQN Q value:  10.048
#  batch mean DQN best action probability:  38.963 %
# ----------
# Epoch 297000/300000
#  batch loss:  0.088
#  running loss:  6.327
#  batch error:  5.95
#  batch avg Phy Q value:  7.993
#  batch avg DQN Q value:  10.09
#  batch mean DQN best action probability:  37.369 %
# ----------
# Epoch 298000/300000
#  batch loss:  0.045
#  running loss:  6.321
#  batch error:  4.516
#  batch avg Phy Q value:  8.251
#  batch avg DQN Q value:  10.303
#  batch mean DQN best action probability:  36.897 %
# ----------
# Epoch 299000/300000
#  batch loss:  1.13
#  running loss:  6.316
#  batch error:  3.304
#  batch avg Phy Q value:  8.552
#  batch avg DQN Q value:  10.128
#  batch mean DQN best action probability:  36.467 %
# ----------
# Epoch 300000/300000
#  batch loss:  0.281
#  running loss:  6.31
#  batch error:  3.316
#  batch avg Phy Q value:  8.301
#  batch avg DQN Q value:  10.225
#  batch mean DQN best action probability:  39.798 %
# ----------
# intermediate evaluation:
# train
# DQN WDR: 11.612
# DQN WIS: 12.644
# ----------
# val
# DQN WDR: 12.221
# DQN WIS: 12.408
# ----------
# test
# DQN WDR: 12.783
# DQN WIS: 11.146
# ----------
# ----------
# Saving interim Model 300000
#
# Training complete in 50m 39s
#
# -----------------
# FINISHED TRAINING ALL EXPERIMENTS
# -----------------
# ess_b32_h128_lr1e4_g99
# Finished at: 2022-06-20 02:11:29.545732
# Experiment complete in 0 hours, 50 minutes and 48 seconds
